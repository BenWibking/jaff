# %% [markdown]
# # Generating C++ Kokkos Chemistry Solvers with JAFF
#
# This notebook demonstrates how to use JAFF to generate C++ code that uses the Kokkos-kernels BDF solver for solving chemical reaction networks. We'll use the `test2.dat` network as an example, which contains only 3 species and 2 reactions.
#
# ## Overview
#
# The Kokkos output plugin generates:
# - **chemistry_ode.hpp**: Chemistry ODE system class with evaluate_function and evaluate_jacobian methods
# - **chemistry_ode.cpp**: Main executable that sets up and runs the BDF solver
# - **CMakeLists.txt**: Build configuration for Kokkos and Kokkos-kernels dependencies
#
# The generated code is compatible with the Kokkos-kernels BDF solver for stiff ODEs.

# %% [markdown]
# ## Step 1: Load the Chemical Network
#
# First, let's load the react_COthin network, which is a carbon-oxygen chemistry network in KROME format.

# %%
from jaff.network import Network
from jaff.builder import Builder
import os

# Load the test2 network
network = Network("../networks/react_COthin")

print(f"Network loaded: {network.label}")
print(f"Number of species: {network.get_number_of_species()}")
print(f"Number of reactions: {len(network.reactions)}")
# Out:
# Welcome to JAFF: Just Another Fancy Format!
# Loading network from ../networks/react_COthin
# Network label = react_COthin
#   8%|████████▏                                                                                                 | 27/350 [00:00<00:01, 192.49it/s]
# KROME variable detected: @var:Hnuclei = get_Hnuclei(n(:))
# KROME variable detected: @var: Te = Tgas*8.617343d-5
# KROME variable detected: @var: invT = 1d0/Tgas
# KROME variable detected: @var: lnTe = log(Te)
# KROME variable detected: @var: T = Tgas
# KROME format detected: @format:idx,R,R,R,P,P,P,P,Tmin,Tmax,rate
# exp(-2.03914985e-6*lnTe**8 + 0.000111954395*lnTe**7 - 0.00263197617*lnTe**6 + 0.0348255977*lnTe**5 - 0.2877056*lnTe**4 + 1.56315498*lnTe**3 - 5.73932875*lnTe**2 + 13.536556*lnTe - 32.71396786)
# 3.92e-13*invTe**0.6353
# exp(-3.071135243196595e-9*lnTe**9 - 1.856767039775261e-8*lnTe**8 + 5.755614137575758e-7*lnTe**7 + 4.989108920299513e-6*lnTe**6 - 1.421502914054107e-5*lnTe**5 - 0.0003212605213188796*lnTe**4 - 0.002380861877349834*lnTe**3 - 0.02026044731984691*lnTe**2 - 0.7241125657826851*lnTe - 28.61303380689232)
# exp(-3.64916141e-6*lnTe**8 + 0.000206723616*lnTe**7 - 0.0050090561*lnTe**6 + 0.0679539123*lnTe**5 - 0.56851189*lnTe**4 + 3.05803875*lnTe**3 - 10.7532302*lnTe**2 + 23.91596563*lnTe - 44.09864886)
# 3.92e-13*invTe**0.6353
# 1.54e-9*(1.0 + 0.3/exp(8.099328789667*invTe))/((Te**1.5*exp(40.49664394833662*invTe))) + 3.92e-13/(Te**0.6353)
# exp(-3.165581065665e-6*lnTe**8 + 0.0001975705312221*lnTe**7 - 0.005324020628287001*lnTe**6 + 0.08113042097303*lnTe**5 - 0.7692466334492*lnTe**4 + 4.701626486759002*lnTe**3 - 18.48066993568*lnTe**2 + 43.93347632635*lnTe - 68.71040990212001)
# KROME format detected: @format:idx,R,R,R,P,P,P,Tmin,Tmax,rate
# 1.25e-15*T32**0.25
# 1.26e-9*exp(-127500.0*invT)/Tgas**0.75
# 4.0e-37*Tgas**4.74
# KROME variable detected: @var:invTe=1d0/Te
# KROME variable detected: @var:logT=log10(Tgas)
# KROME variable detected: @var:invsqrT=1d0/sqrt(Tgas)
# KROME variable detected: @var:kl11 = 1d1**(-27.029d0+3.801d0*logT-29487d0*invT)
# KROME variable detected: @var:kh11 = 1d1**(-2.729d0-1.75d0*logT-23474d0*invT)
# KROME variable detected: @var:ncr11 = 1d1**(5.0792d0*(1d0-1.23d-5*(Tgas-2d3)))
# KROME variable detected: @var:a11=1.d0/(1.d0+(Hnuclei/(ncr11+1d-40)))
# kh11**(1.0 - a11)*kl11**a11
# 7.20000000000000e-15
# KROME format detected: @format:idx,R,R,R,P,P,P,Tmin,Tmax,rate
# 3.7e-14*exp(35.0*invT)
# 3.0e-11*sqrt(T32)*exp(-52000.0*invT)
# 3.36e-10/(sqrTgas*((Tgas*1.0e-6)**0.7 + 1.0)*((Tgas*0.001)**0.2))
# 6.77e-15*Te**0.8779
# 1.43000000000000e-9
# exp(2.238306228891639e-7*lnTe**7 - 8.36671960467864e-6*lnTe**6 + 0.0001073294010367247*lnTe**5 - 0.0003105115447124016*lnTe**4 - 0.004555120027032095*lnTe**3 + 0.03599837721023835*lnTe**2 + 0.2289800603272916*lnTe - 20.06913897587003)
# 1.85e-23*Tgas**1.8
# 5.81e-16/(Tgas/56200.0)**(0.6657*log10(Tgas/56200.0))
# 6.00000000000000e-10
# exp(-9.36345888928611e-6*lnTe**8 + 0.0004138398421504563*lnTe**7 - 0.007879026154483455*lnTe**6 + 0.0841077503763412*lnTe**5 - 0.5416182856220388*lnTe**4 + 2.045587822403071*lnTe**3 - 3.898003964650152*lnTe**2 + 3.400824447095291*lnTe - 24.24914687731536)
# 5.6e-11*Tgas**0.5*exp(-102124.0*invT)
# 1.0670825e-10*Te**2.012*exp(-4.463*invTe)/((0.2472*Te + 1.0)**3.512)
# exp(-2.631285809207e-6*lnTe**8 + 0.0001068275202678*lnTe**7 - 0.001656194699504*lnTe**6 + 0.01178329782711*lnTe**5 - 0.03365012031362999*lnTe**4 + 0.01623316639567*lnTe**3 - 0.2827443061704*lnTe**2 + 2.360852208681*lnTe - 18.01849334273)
#  14%|██████████████▊                                                                                           | 49/350 [00:00<00:01, 204.87it/s]
# 2.56e-9*Te**1.78186
# exp(-8.06838246118e-8*lnTe**9 + 2.4555011970392e-6*lnTe**8 - 2.585009680264e-5*lnTe**7 + 8.66396324309e-5*lnTe**6 + 0.0002012250284791*lnTe**5 - 0.0014327641212992*lnTe**4 + 0.00846445538663*lnTe**3 - 0.1421013521554148*lnTe**2 + 1.139449335841631*lnTe - 20.37260896533324)
# 6.5e-9/(sqrt(Te))
# 1.0e-8/Tgas**0.4
# 1.00000000000000e-8
# 1.32e-6/Tgas**0.76
# 5.0e-7*sqrt(100.0*invT)
# KROME variable detected: @var:kl21 = 1.18d-10*exp(-6.95d4*invT)
# KROME variable detected: @var:kh21 = 8.125d-8*invsqrT*exp(-5.2d4*invT)*(1.d0-exp(-6d3*invT))
# KROME variable detected: @var:ncr21 = 1d1**(4.845d0-1.3d0*log10(T*1d-4)+1.62d0*log10(T*1d-4)**2)
# KROME variable detected: @var:a21=1.d0/(1.d0+(Hnuclei/(ncr21+1d-40)))
# kh21**(1.0 - a21)*kl21**a21
#  20%|█████████████████████▏                                                                                    | 70/350 [00:00<00:01, 190.20it/s]
# 6.9e-32/Tgas**0.4
# 1.3e-32/T32**0.38
# 1.3e-32/T32**1.0
# 1.3e-32/(8.0*T32**0.38)
# 1.3e-32/(8.0*T32**1.0)
# 4.67e-12/T32**0.6
# 1.23e-17*T32**2.49*exp(21845.6*invT)
# 9.62e-8*exp(-115786.2*invT)/T32**1.37
# 7.5e-12/T32**0.55
# 4.86e-12/T32**0.32
# 1.3e-10/Tgas**0.64
# 0.00074*(1.0 + 0.062*exp(-145000.0*invT))*exp(-175000.0*invT)/Tgas**1.5 + 1.41e-10/Tgas**0.66
# KROME variable detected: @var:u1 = 11.26d0*invTe
# KROME variable detected: @var:u2 = 8.2d0*invTe
# KROME variable detected: @var:u3 = 13.6*invTe
# KROME format detected: @format:idx,R,R,R,P,P,P,P,Tmin,Tmax,rate
# 6.85e-8*u1**0.25*exp(-u1)/(u1 + 0.193)
# 1.88e-7*u2**0.25*(u2**0.5 + 1.0)*exp(-u2)/(u2 + 0.376)
# 3.59e-8*u3**0.34*exp(-u3)/(u3 + 0.073)
# 4.99e-11*Tgas**0.405 + 7.54e-10*invT**0.458
# (4.0e-10*Tgas**0.00669 + 1.08e-11*Tgas**0.517)*exp(-227.0*invT)
# 2.78e-15*exp(-Tgas*1.2258e-6)/(Tgas*0.0001)**0.2163 + 4.991e-15*(Tgas*0.0001)**0.3794*exp(-Tgas*8.9206e-7)
# 3.9e-16*Tgas**0.213
# 6.08e-14*(Tgas*0.0001)**1.96*exp(-170000.0*invT)
# 8.58e-17*Tgas**0.757
# 3.25e-17*Tgas**0.968
# 2.77e-19*Tgas**1.597
# 5.88e-13*Tgas**0.848
# 1.45e-13*Tgas
# 3.30000000000000e-9
# 2.10000000000000e-9
# 4.1e-10*(Tgas*0.0001)**0.24*(3.17*exp(Tgas*4.184e-7) + 1.0)*exp(-3.178*invTe)
# 1.23e-9*(Tgas*0.0001)**0.24*(3.17*exp(Tgas*4.184e-7) + 1.0)
# 1.75e-12/(Tgas/10000.0)**0.6346
# 6.0e-9*exp(-50900.0*invT)
#  28%|█████████████████████████████▉                                                                            | 99/350 [00:00<00:01, 224.97it/s]
# KROME format detected: @format:idx,R,R,P,P,Tmin,Tmax,rate
# 3.00000000000000e-10
# 1.14000000000000e-9
# 8.68e-10*(0.0242717*sqrt(300.0*invT) + 7.1537*invT + 1.0)
# 6.64e-10*exp(-11700.0*invT)
# 1.31e-10*exp(-80.0*invT)
# 5.46e-10*exp(-1943.0*invT)
# 2.40000000000000e-10
# 6.60000000000000e-11
# 1.02e-10*exp(-914.0*invT)
# 1.9e-11*exp(-165.1*invT)/T32**2.2
# 2.52e-11*exp(-2381.0*invT)
# 2.20000000000000e-10
# KROME format detected: @format:idx,R,R,P,P,P,Tmin,Tmax,rate
# 2.04e-10*exp(-270.0*invT)
# KROME format detected: @format:idx,R,R,P,P,Tmin,Tmax,rate
# 1.36e-10*exp(-270.0*invT)
# 5.01000000000000e-11
# 4.98e-10*exp(-6000.0*invT)
# 2.0e-12/T32**0.12
# 2.0e-12*T32**0.757
# 1.46e-12*exp(-9650.0*invT)
# 6.99e-14*T32**2.8*exp(-1950.0*invT)
# 3.6e-16*T**1.52*exp(-1740.0*invT)
# 3.68000000000000e-10
# 2.25e-11*exp(-0.108*invT)/T32**0.339
# 2.4e-11*exp(-110.0*invT)
# 2.42000000000000e-12
# 6.2e-14*T32**2.62*exp(-945.0*invT)
# 1.38000000000000e-12
# 1.65e-12*T32**1.14*exp(-50.0*invT)
# 1.59e-11*T32*1.2*exp(-9610.0*invT)
# 2.61e-10*1.2*exp(-8156.0*invT)
# 3.16e-10*exp(-21890.0*invT)
# 4.7e-11/T32**0.34
# 2.48e-12*T32**1.54*exp(613.0*invT)
# 1.1e-10*T32**0.5*exp(-77700.0*invT)
# 2.24e-9*T32**0.042*exp((-Tgas)/46600.0)
# 7.7e-9*exp(-17560.0*invT)
# 2.40000000000000e-9
# (7.2733e-11*sqrt(Tgas) + 5.9203e-14*Tgas + 1.0218e-9)/(Tgas**0.1667 + 0.044914*sqrt(Tgas) - 5.9203e-14*Tgas + 2.6397e-6*Tgas**1.5)
# 8.5145e-10/(Tgas**0.1667 + 0.00095666*sqrt(Tgas) - 4.404e-5*Tgas + 2.3496e-6*Tgas**1.5)
# 1.0e-10*exp(-4640.0*invT)
# 7.50000000000000e-10
# 1.20000000000000e-9
# 3.50000000000000e-10
#  48%|██████████████████████████████████████████████████                                                       | 167/350 [00:00<00:00, 373.52it/s]
# 1.0e-9*exp(-7080.0*invT)
# 1.60000000000000e-9
# 7.50000000000000e-10
# 7.0e-10*exp(-10560.0*invT)
# 2.50000000000000e-10
# 2.50000000000000e-10
# 4.80000000000000e-10
# 1.69000000000000e-9
# 1.50000000000000e-9
# 7.98e-10*exp(-1.41*invT)/T32**0.156
# 3.42e-10*exp(-1.41*invT)/T32**0.156
# 2.28000000000000e-8
# 1.52e-9*(2.62185*(300.0*invT)**0.5 + 0.62)
# 2.28000000000000e-8
# 9.15e-10*(2.62185*(300.0*invT)**0.5 + 0.62)
# 1.01000000000000e-9
# 6.40000000000000e-10
# 2.55000000000000e-8
# 1.73e-9*(2.578947*(300.0*invT)**0.5 + 0.62)
# 1.80000000000000e-9
# 5.03000000000000e-9
# 3.4093e-10*(2.578947*(300.0*invT)**0.5 + 0.62)
# 2.40000000000000e-10
# 1.00000000000000e-11
# 3.42000000000000e-10
# 4.53000000000000e-10
# 9.10000000000000e-10
# 5.20000000000000e-11
# 5.20000000000000e-11
# 2.47000000000000e-9
# 1.88055e-9*(1.79558*invT + 0.02427*(300.0*invT)**0.5 + 1.0)
# 1.45000000000000e-10
# 1.08256e-10*(1.79558*invT + 0.02427*(300.0*invT)**0.5 + 1.0)
# 1.00000000000000e-9
# 1.23000000000000e-8
# 8.34e-10*(834.16588*invT + 0.5232*(300.0*invT)**0.5 + 1.0)
# 3.30000000000000e-8
# 3.54e-9*(1.587411*(300.0*invT)**0.5 + 0.62)
# 1.765e-9*(0.672147*(300.0*invT)**0.5 + 0.62)
# 1.765e-9*(56.66255*invT + 0.136347*(300.0*invT)**0.5 + 1.0)
# 1.765e-9*(0.672147*(300.0*invT)**0.5 + 0.62)
# 1.765e-9*(56.66255*invT + 0.136347*(300.0*invT)**0.5 + 1.0)
# KROME format detected: @format:idx,R,R,P,P,P,Tmin,Tmax,rate
# 9.65e-10*(0.672147*(300.0*invT)**0.5 + 0.62)
# 9.65e-10*(56.6625498765*invT + 0.136347*(300.0*invT)**0.5 + 1.0)
# 9.65e-10*(0.672147*(300.0*invT)**0.5 + 0.62)
# 9.65e-10*(56.6625498765*invT + 0.136347*(300.0*invT)**0.5 + 1.0)
# 1.60000000000000e-9
# KROME format detected: @format:idx,R,R,P,P,Tmin,Tmax,rate
# 3.75000000000000e-8
# 2.5e-9*(2.62185*(300.0*invT)**0.5 + 0.62)
# KROME format detected: @format:idx,R,R,P,P,P,Tmin,Tmax,rate
# 2.20000000000000e-8
# 1.35e-9*(2.62185*(300.0*invT)**0.5 + 0.62)
# KROME format detected: @format:idx,R,R,P,P,Tmin,Tmax,rate
# 4.20000000000000e-8
# 2.85e-9*(2.578947*(300.0*invT)**0.5 + 0.62)
# KROME format detected: @format:idx,R,R,P,P,P,Tmin,Tmax,rate
# 7.56000000000000e-9
# 5.1282e-10*(2.578947*(300.0*invT)**0.5 + 0.62)
# 7.56000000000000e-9
# 5.1282e-10*(2.578947*(300.0*invT)**0.5 + 0.62)
# KROME format detected: @format:idx,R,R,P,P,Tmin,Tmax,rate
# 7.56000000000000e-9
# 5.1282e-10*(2.578947*(300.0*invT)**0.5 + 0.62)
# 2.00000000000000e-9
# 3.30000000000000e-11
# KROME format detected: @format:idx,R,R,P,P,P,Tmin,Tmax,rate
# 1.10000000000000e-9
# 1.4e-9/T32**0.5
# 1.4e-16/T32**0.5
# KROME format detected: @format:idx,R,R,P,P,Tmin,Tmax,rate
# 7.50000000000000e-10
# 2.3e-7/T32**0.5
# 2.3e-7/T32**0.5
# 2.3e-7/T32**0.5
# 2.34e-8/T32**0.52
# KROME format detected: @format:idx,R,R,P,P,P,Tmin,Tmax,rate
# 4.36e-8/T32**0.52
# KROME format detected: @format:idx,R,R,P,P,Tmin,Tmax,rate
# 7.0e-8/T32**0.5
# 1.6e-7/T32**0.6
# 7.68e-8/T32**0.6
# KROME format detected: @format:idx,R,R,P,P,P,Tmin,Tmax,rate
# 4.03e-7/T32**0.6
# KROME format detected: @format:idx,R,R,P,P,Tmin,Tmax,rate
# 7.75e-8/T32**0.5
# 1.95e-7/T32**0.5
# KROME format detected: @format:idx,R,R,P,P,P,Tmin,Tmax,rate
# 2.0e-7/T32**0.5
# KROME format detected: @format:idx,R,R,P,P,Tmin,Tmax,rate
# 6.3e-9/T32**0.48
# 3.9e-8/T32**0.5
# 8.6e-8/T32**0.5
# KROME format detected: @format:idx,R,R,P,P,P,Tmin,Tmax,rate
# 3.05e-7/T32**0.5
# 2.58e-7/T32**0.5
# 5.6e-9/T32**0.5
# KROME format detected: @format:idx,R,R,P,P,Tmin,Tmax,rate
# 1.08e-7/T32**0.5
# 6.02e-7/T32**0.5
# 1.95e-7/T32**0.7
# 2.75e-7/T32**0.55
# 2.76e-7/T32**0.64
# 2.4e-8/T32**0.64
# 1.1e-7*invT32
# 1.00000000000000e-9
# 1.00000000000000e-10
# 5.00000000000000e-10
# 1.00000000000000e-13
# 5.00000000000000e-10
# 5.00000000000000e-10
# 7.00000000000000e-10
# 7.00000000000000e-10
# 5.00000000000000e-10
# 6.4e-10*exp(-21300.0*invT)
# KROME format detected: @format:idx,R,R,P,P,P,Tmin,Tmax,rate
# 3.0e-11*T32**0.5*exp(-52000.0*invT)
# KROME format detected: @format:idx,R,R,P,Tmin,Tmax,rate
# 1.00000000000000e-16
# KROME format detected: @format:idx,R,R,P,P,Tmin,Tmax,rate
# 2.25000000000000e-15
# 1.00000000000000e-17
# 1.00000000000000e-17
# 4.36e-18*T32**0.35*exp(-161.3*invT)
# 1.00000000000000e-19
# 3.09e-17*T32**0.33*exp(-1629.0*invT)
# 4.46e-16*exp(-4.93/Tgas**0.6667)/Tgas**0.5
# 2.0e-16*exp(-23.0*invTgas)/T32**1.3
# 2.50000000000000e-18
# 3.14e-18*exp(-68.0*invT)/T32**0.15
#  76%|████████████████████████████████████████████████████████████████████████████████                         | 267/350 [00:00<00:00, 573.56it/s]
# 1.50000000000000e-15
# 9.9e-19/T32**0.38
# 4.9e-20*T32**1.58
# 5.26e-18*exp(-90.0*invT)/T32**5.22
# KROME format detected: @format:idx,R,R,P,rate
# KROME variable detected: @var:fA = 1d0/(1d0+1d4*exp(-6d2/(user_Tdust+1d-40)))
# 3.0e-18*Hnuclei*sqrt(Tgas)*fA/((8.0e-6*Tgas**2 + 0.002*Tgas + 0.04*sqrt(Tgas + user_Tdust) + 1.0)*n(idx_H))
# KROME format detected: @format:idx,R,P,P,rate
# 7.1e-7*exp(-0.5*user_Av)
# 1.1e-9*exp(-1.9*user_Av)
# KROME variable detected: @var: user_H2self = fselfH2(1.87d21*(merge(n(idx_H2),n_global(idx_H2),n(idx_H2) > 0.0_8)*1d-3)**(2./3.), 1d5)
# 5.6e-11*user_H2self*exp(-3.74*user_Av)
# 4.9e-13*exp(-1.8*user_Av)
# 4.9e-13*exp(-2.3*user_Av)
# 3.1e-10*exp(-3.0*user_Av)
# 2.4e-7*exp(-0.9*user_Av)
# 8.7e-10*exp(-1.2*user_Av)
# 7.7e-10*exp(-2.8*user_Av)
# 2.6e-10*exp(-2.5*user_Av)
# 7.1e-10*exp(-1.7*user_Av)
# 5.9e-10*exp(-2.3*user_Av)
# 4.6e-10*exp(-1.7*user_Av)
# 1.0e-9*exp(-1.7*user_Av)
# 1.0e-9*exp(-1.7*user_Av)
# 1.5e-10*exp(-2.1*user_Av)
# 2.4e-7*exp(-0.5*user_Av)
# 3.7e-10*exp(-1.7*user_Av)
# 1.6e-12*exp(-3.1*user_Av)
# 1.0e-12*exp(-1.8*user_Av)
# 6.0e-10*exp(-1.7*user_Av)
# 3.2e-11*exp(-3.9*user_Av)
# KROME variable detected: @var: HnOj = fHnOj(user_Av)
# 5.0e-11*HnOj
# 5.0e-11*HnOj
# 5.0e-11*HnOj
# 1.5e-10*HnOj
# 2.5e-11*HnOj
# 2.5e-11*HnOj
# 7.5e-12*HnOj
# 2.5e-11*HnOj
# 5.6e-11*exp(-3.7*user_Av)
# 7.0e-10*exp(-1.8*user_Av)
# 2.0e-10*exp(-3.53*user_Av)
# 0.46*crate
# 0.5*crate
# 2.8*crate
# 5.0*crate
# 3.0*crate
# 237.0*crate
# 0.1*crate
# 0.0003*crate
# 0.93*crate
# 1020.0*crate
# 730.0*crate
# 750.0*crate
# 117.0*crate
# 510.0*crate
# 500.0*crate
# 970.0*crate
# 421.0*crate
# 1170.0*crate
# KROME format detected: @format:idx,R,P,P,P,rate
# 0.93*crate
# KROME variable detected: @var:ntot=sum(n(1:nmols))
# WARNING: could not parse variable (invalid syntax (<unknown>, line 1)), using string instead
# KROME format detected: @format:idx,R,R,P,Tmin,Tmax,rate
# 5.99e-33*ntot/(Tgas/5000.0)**1.6
# WARNING: variable ntot not replaced because it is a string, not a sympy expression
# 5.99e-33*ntot*exp(5255.0/Tgas)/(Tgas/5000.0)**0.64
# WARNING: variable ntot not replaced because it is a string, not a sympy expression
# 6.16e-29*ntot/(Tgas/300.0)**3.08
# WARNING: variable ntot not replaced because it is a string, not a sympy expression
# 2.14e-29*ntot*exp(2114.0/Tgas)/(Tgas/300.0)**3.08
# WARNING: variable ntot not replaced because it is a string, not a sympy expression
# 6.16e-27*ntot/(Tgas/300.0)**3.08
# WARNING: variable ntot not replaced because it is a string, not a sympy expression
# 2.14e-27*ntot*exp(2114.0/Tgas)/(Tgas/300.0)**3.08
# WARNING: variable ntot not replaced because it is a string, not a sympy expression
# 6.16e-27*ntot/(Tgas/300.0)**3.08
# WARNING: variable ntot not replaced because it is a string, not a sympy expression
# 2.14e-27*ntot*exp(2114.0/Tgas)/(Tgas/300.0)**3.08
# WARNING: variable ntot not replaced because it is a string, not a sympy expression
# 4.33e-32*ntot/T32
# WARNING: variable ntot not replaced because it is a string, not a sympy expression
# 2.56e-31*ntot/T32**2
# WARNING: variable ntot not replaced because it is a string, not a sympy expression
# 9.2e-34*ntot/T32
# WARNING: variable ntot not replaced because it is a string, not a sympy expression
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 350/350 [00:00<00:00, 456.14it/s]
# Variables found: ['HnOj', 'Hnuclei', 'T', 'T32', 'Te', 'Tgas', 'crate', 'fA', 'idx_H', 'invT', 'invT32', 'invTe', 'invTgas', 'lnTe', 'n', 'ntot', 'sqrTgas', 'tgas', 'user_Av', 'user_H2self', 'user_Tdust']
# Loaded 287 reactions
# Lodaded 0 photo-chemistry reactions
# WARNING: isomer detected: HOC+ HCO+
# All done!
# Network loaded: react_COthin
# Number of species: 37
# Number of reactions: 287

# %% [markdown]
# ## Step 2: Examine Network Properties
#
# Let's examine some properties of the network to understand what we're working with.

# %%
for i, species in enumerate(network.species):
    print(f"  {i}: {species.name} (mass: {species.mass:.2f}, charge: {species.charge})")

print(f"\nTotal species: {len(network.species)}")
# Out:
#   0: H (mass: 0.00, charge: 0)
#   1: e- (mass: 0.00, charge: -1)
#   2: H+ (mass: 0.00, charge: 1)
#   3: He (mass: 0.00, charge: 0)
#   4: He+ (mass: 0.00, charge: 1)
#   5: He++ (mass: 0.00, charge: 2)
#   6: H2 (mass: 0.00, charge: 0)
#   7: H2+ (mass: 0.00, charge: 1)
#   8: H- (mass: 0.00, charge: -1)
#   9: C+ (mass: 0.00, charge: 1)
#   10: C (mass: 0.00, charge: 0)
#   11: Si+ (mass: 0.00, charge: 1)
#   12: Si (mass: 0.00, charge: 0)
#   13: O+ (mass: 0.00, charge: 1)
#   14: O (mass: 0.00, charge: 0)
#   15: Si++ (mass: 0.00, charge: 2)
#   16: OH (mass: 0.00, charge: 0)
#   17: HOC+ (mass: 0.00, charge: 1)
#   18: HCO+ (mass: 0.00, charge: 1)
#   19: CO (mass: 0.00, charge: 0)
#   20: CH (mass: 0.00, charge: 0)
#   21: CH2 (mass: 0.00, charge: 0)
#   22: C2 (mass: 0.00, charge: 0)
#   23: HCO (mass: 0.00, charge: 0)
#   24: H2O (mass: 0.00, charge: 0)
#   25: O2 (mass: 0.00, charge: 0)
#   26: H3+ (mass: 0.00, charge: 1)
#   27: CH+ (mass: 0.00, charge: 1)
#   28: CH2+ (mass: 0.00, charge: 1)
#   29: CO+ (mass: 0.00, charge: 1)
#   30: CH3+ (mass: 0.00, charge: 1)
#   31: OH+ (mass: 0.00, charge: 1)
#   32: H2O+ (mass: 0.00, charge: 1)
#   33: H3O+ (mass: 0.00, charge: 1)
#   34: O2+ (mass: 0.00, charge: 1)
#   35: C- (mass: 0.00, charge: -1)
#   36: O- (mass: 0.00, charge: -1)
#
# Total species: 37

# %%
# Show a few example reactions
for i, reaction in enumerate(network.reactions):
    reactants = " + ".join([f"{r.name}" for r in reaction.reactants])
    products = " + ".join([f"{p.name}" for p in reaction.products])
    print(f"  {i+1}: {reactants} -> {products}")
    print(f"      Rate: {reaction.get_sympy()}")
    print()
# Out:
#   1: H + e- -> H+ + e- + e-
#       Rate: exp(-2.03914985e-6*lnTe**8 + 0.000111954395*lnTe**7 - 0.00263197617*lnTe**6 + 0.0348255977*lnTe**5 - 0.2877056*lnTe**4 + 1.56315498*lnTe**3 - 5.73932875*lnTe**2 + 13.536556*lnTe - 32.71396786)
#
#   2: H+ + e- -> H
#       Rate: 3.92e-13*invTe**0.6353
#
#   3: H+ + e- -> H
#       Rate: exp(-3.071135243196595e-9*lnTe**9 - 1.856767039775261e-8*lnTe**8 + 5.755614137575758e-7*lnTe**7 + 4.989108920299513e-6*lnTe**6 - 1.421502914054107e-5*lnTe**5 - 0.0003212605213188796*lnTe**4 - 0.002380861877349834*lnTe**3 - 0.02026044731984691*lnTe**2 - 0.7241125657826851*lnTe - 28.61303380689232)
#
#   4: He + e- -> He+ + e- + e-
#       Rate: exp(-3.64916141e-6*lnTe**8 + 0.000206723616*lnTe**7 - 0.0050090561*lnTe**6 + 0.0679539123*lnTe**5 - 0.56851189*lnTe**4 + 3.05803875*lnTe**3 - 10.7532302*lnTe**2 + 23.91596563*lnTe - 44.09864886)
#
#   5: He+ + e- -> He
#       Rate: 3.92e-13*invTe**0.6353
#
#   6: He+ + e- -> He
#       Rate: 1.54e-9*(1.0 + 0.3/exp(8.099328789667*invTe))/((Te**1.5*exp(40.49664394833662*invTe))) + 3.92e-13/(Te**0.6353)
#
#   7: He+ + e- -> He++ + e- + e-
#       Rate: exp(-3.165581065665e-6*lnTe**8 + 0.0001975705312221*lnTe**7 - 0.005324020628287001*lnTe**6 + 0.08113042097303*lnTe**5 - 0.7692466334492*lnTe**4 + 4.701626486759002*lnTe**3 - 18.48066993568*lnTe**2 + 43.93347632635*lnTe - 68.71040990212001)
#
#   8: He+ + H -> He + H+
#       Rate: 1.25e-15*T32**0.25
#
#   9: He + H+ -> He+ + H
#       Rate: 1.26e-9*exp(-127500.0*invT)/Tgas**0.75
#
#   10: He + H+ -> He+ + H
#       Rate: 4.0e-37*Tgas**4.74
#
#   11: H2 + He -> H + H + He
#       Rate: (10.0**(-1.75*log10(tgas) - 2.729 - 23474.0/tgas))**(1.0 - 1.0/(1.0 + get_hnuclei(n)/(10.0**(5.0792*(1.0 - 1.23e-5*(tgas - 1*2000.0))) + 1.0e-40)))*(10.0**(3.801*log10(tgas) - 27.029 - 29487.0/tgas))**(1.0/(1.0 + get_hnuclei(n)/(10.0**(5.0792*(1.0 - 1.23e-5*(tgas - 1*2000.0))) + 1.0e-40)))
#
#   12: H2 + He+ -> He + H2+
#       Rate: 7.20000000000000E-15
#
#   13: H2 + He+ -> He + H + H+
#       Rate: 3.7e-14*exp(35.0*invT)
#
#   14: H2 + He+ -> He+ + H + H
#       Rate: 3.0e-11*sqrt(T32)*exp(-52000.0*invT)
#
#   15: He++ + e- -> He+
#       Rate: 3.36e-10/(sqrTgas*((Tgas*1.0e-6)**0.7 + 1.0)*((Tgas*0.001)**0.2))
#
#   16: H + e- -> H-
#       Rate: 6.77e-15*Te**0.8779
#
#   17: H- + H -> H2 + e-
#       Rate: 1.43000000000000E-9
#
#   18: H- + H -> H2 + e-
#       Rate: exp(2.238306228891639e-7*lnTe**7 - 8.36671960467864e-6*lnTe**6 + 0.0001073294010367247*lnTe**5 - 0.0003105115447124016*lnTe**4 - 0.004555120027032095*lnTe**3 + 0.03599837721023835*lnTe**2 + 0.2289800603272916*lnTe - 20.06913897587003)
#
#   19: H + H+ -> H2+
#       Rate: 1.85e-23*Tgas**1.8
#
#   20: H + H+ -> H2+
#       Rate: 5.81e-16/(Tgas/56200.0)**(0.6657*log10(Tgas/56200.0))
#
#   21: H2+ + H -> H2 + H+
#       Rate: 6.00000000000000E-10
#
#   22: H2 + H+ -> H2+ + H
#       Rate: exp(-9.36345888928611e-6*lnTe**8 + 0.0004138398421504563*lnTe**7 - 0.007879026154483455*lnTe**6 + 0.0841077503763412*lnTe**5 - 0.5416182856220388*lnTe**4 + 2.045587822403071*lnTe**3 - 3.898003964650152*lnTe**2 + 3.400824447095291*lnTe - 24.24914687731536)
#
#   23: H2 + e- -> H + H + e-
#       Rate: 5.6e-11*Tgas**0.5*exp(-102124.0*invT)
#
#   24: H2 + H -> H + H + H
#       Rate: 1.0670825e-10*Te**2.012*exp(-4.463*invTe)/((0.2472*Te + 1.0)**3.512)
#
#   25: H- + e- -> H + e- + e-
#       Rate: exp(-2.631285809207e-6*lnTe**8 + 0.0001068275202678*lnTe**7 - 0.001656194699504*lnTe**6 + 0.01178329782711*lnTe**5 - 0.03365012031362999*lnTe**4 + 0.01623316639567*lnTe**3 - 0.2827443061704*lnTe**2 + 2.360852208681*lnTe - 18.01849334273)
#
#   26: H- + H -> H + H + e-
#       Rate: 2.56e-9*Te**1.78186
#
#   27: H- + H -> H + H + e-
#       Rate: exp(-8.06838246118e-8*lnTe**9 + 2.4555011970392e-6*lnTe**8 - 2.585009680264e-5*lnTe**7 + 8.66396324309e-5*lnTe**6 + 0.0002012250284791*lnTe**5 - 0.0014327641212992*lnTe**4 + 0.00846445538663*lnTe**3 - 0.1421013521554148*lnTe**2 + 1.139449335841631*lnTe - 20.37260896533324)
#
#   28: H- + H+ -> H + H
#       Rate: 6.5e-9/(sqrt(Te))
#
#   29: H- + H+ -> H2+ + e-
#       Rate: 1.0e-8/Tgas**0.4
#
#   30: H2+ + e- -> H + H
#       Rate: 1.00000000000000E-8
#
#   31: H2+ + e- -> H + H
#       Rate: 1.32e-6/Tgas**0.76
#
#   32: H2+ + H- -> H + H2
#       Rate: 5.0e-7*sqrt(100.0*invT)
#
#   33: H2 + H2 -> H + H + H2
#       Rate: (1.18e-10*exp(-69500.0/tgas))**(1.0/(1.0 + get_hnuclei(n)/(10.0**(1.62*log10(0.0001*tgas)**2 - 1.3*log10(0.0001*tgas) + 4.845) + 1.0e-40)))*(8.125e-8*(1.0 - exp(-6000.0/tgas))*exp(-52000.0/tgas)/sqrt(tgas))**(1.0 - 1.0/(1.0 + get_hnuclei(n)/(10.0**(1.62*log10(0.0001*tgas)**2 - 1.3*log10(0.0001*tgas) + 4.845) + 1.0e-40)))
#
#   34: H + H + He -> H2 + He
#       Rate: 6.9e-32/Tgas**0.4
#
#   35: H + H + H -> H2 + H
#       Rate: 1.3e-32/T32**0.38
#
#   36: H + H + H -> H2 + H
#       Rate: 1.3e-32/T32**1.0
#
#   37: H2 + H + H -> H2 + H2
#       Rate: 1.3e-32/(8.0*T32**0.38)
#
#   38: H2 + H + H -> H2 + H2
#       Rate: 1.3e-32/(8.0*T32**1.0)
#
#   39: C+ + e- -> C
#       Rate: 4.67e-12/T32**0.6
#
#   40: C+ + e- -> C
#       Rate: 1.23e-17*T32**2.49*exp(21845.6*invT)
#
#   41: C+ + e- -> C
#       Rate: 9.62e-8*exp(-115786.2*invT)/T32**1.37
#
#   42: Si+ + e- -> Si
#       Rate: 7.5e-12/T32**0.55
#
#   43: Si+ + e- -> Si
#       Rate: 4.86e-12/T32**0.32
#
#   44: O+ + e- -> O
#       Rate: 1.3e-10/Tgas**0.64
#
#   45: O+ + e- -> O
#       Rate: 0.00074*(1.0 + 0.062*exp(-145000.0*invT))*exp(-175000.0*invT)/Tgas**1.5 + 1.41e-10/Tgas**0.66
#
#   46: C + e- -> C+ + e- + e-
#       Rate: 1.30236232447661e-6*exp(-130666.726391186/Max(2.73, Min(100000000.0, tgas)))/((0.193 + 130666.726391186/Max(2.73, Min(100000000.0, tgas)))*Max(2.73, Min(100000000.0, tgas))**0.25)
#
#   47: Si + e- -> Si+ + e- + e-
#       Rate: 3.30193080082499e-6*(308.47518711625/Max(2.73, Min(100000000.0, tgas))**0.5 + 1.0)*exp(-95156.9410664053/Max(2.73, Min(100000000.0, tgas)))/((0.376 + 95156.9410664053/Max(2.73, Min(100000000.0, tgas)))*Max(2.73, Min(100000000.0, tgas))**0.25)
#
#   48: O + e- -> O+ + e- + e-
#       Rate: 2.10121614119865e-6*exp(-157821.268110136/Max(2.73, Min(100000000.0, tgas)))/((0.073 + 157821.268110136/Max(2.73, Min(100000000.0, tgas)))*Max(2.73, Min(100000000.0, tgas))**0.34)
#
#   49: O+ + H -> O + H+
#       Rate: 4.99e-11*Tgas**0.405 + 7.54e-10*invT**0.458
#
#   50: O + H+ -> O+ + H
#       Rate: (4.0e-10*Tgas**0.00669 + 1.08e-11*Tgas**0.517)*exp(-227.0*invT)
#
#   51: O + He+ -> O+ + He
#       Rate: 2.78e-15*exp(-Tgas*1.2258e-6)/(Tgas*0.0001)**0.2163 + 4.991e-15*(Tgas*0.0001)**0.3794*exp(-Tgas*8.9206e-7)
#
#   52: C + H+ -> C+ + H
#       Rate: 3.9e-16*Tgas**0.213
#
#   53: C+ + H -> C + H+
#       Rate: 6.08e-14*(Tgas*0.0001)**1.96*exp(-170000.0*invT)
#
#   54: C + He+ -> C+ + He
#       Rate: 8.58e-17*Tgas**0.757
#
#   55: C + He+ -> C+ + He
#       Rate: 3.25e-17*Tgas**0.968
#
#   56: C + He+ -> C+ + He
#       Rate: 2.77e-19*Tgas**1.597
#
#   57: Si + H+ -> Si+ + H
#       Rate: 5.88e-13*Tgas**0.848
#
#   58: Si + H+ -> Si+ + H
#       Rate: 1.45e-13*Tgas
#
#   59: Si + He+ -> Si+ + He
#       Rate: 3.30000000000000E-9
#
#   60: C+ + Si -> C + Si+
#       Rate: 2.10000000000000E-9
#
#   61: Si+ + H+ -> Si++ + H
#       Rate: 4.1e-10*(Tgas*0.0001)**0.24*(3.17*exp(Tgas*4.184e-7) + 1.0)*exp(-3.178*invTe)
#
#   62: Si++ + H -> Si+ + H+
#       Rate: 1.23e-9*(Tgas*0.0001)**0.24*(3.17*exp(Tgas*4.184e-7) + 1.0)
#
#   63: Si++ + e- -> Si+
#       Rate: 1.75e-12/(Tgas/10000.0)**0.6346
#
#   64: OH + H -> O + H + H
#       Rate: 6.0e-9*exp(-50900.0*invT)
#
#   65: HOC+ + H2 -> HCO+ + H2
#       Rate: 3.00000000000000E-10
#
#   66: HOC+ + CO -> HCO+ + CO
#       Rate: 1.14000000000000E-9
#
#   67: HOC+ + CO -> HCO+ + CO
#       Rate: 8.68e-10*(0.0242717*sqrt(300.0*invT) + 7.1537*invT + 1.0)
#
#   68: C + H2 -> CH + H
#       Rate: 6.64e-10*exp(-11700.0*invT)
#
#   69: CH + H -> C + H2
#       Rate: 1.31e-10*exp(-80.0*invT)
#
#   70: CH + H2 -> CH2 + H
#       Rate: 5.46e-10*exp(-1943.0*invT)
#
#   71: CH + C -> C2 + H
#       Rate: 2.40000000000000E-10
#
#   72: CH + O -> CO + H
#       Rate: 6.60000000000000E-11
#
#   73: CH + O -> CO + H
#       Rate: 1.02e-10*exp(-914.0*invT)
#
#   74: CH + O -> HCO+ + e-
#       Rate: 1.9e-11*exp(-165.1*invT)/T32**2.2
#
#   75: CH + O -> OH + C
#       Rate: 2.52e-11*exp(-2381.0*invT)
#
#   76: CH2 + H -> CH + H2
#       Rate: 2.20000000000000E-10
#
#   77: CH2 + O -> CO + H + H
#       Rate: 2.04e-10*exp(-270.0*invT)
#
#   78: CH2 + O -> CO + H2
#       Rate: 1.36e-10*exp(-270.0*invT)
#
#   79: CH2 + O -> HCO + H
#       Rate: 5.01000000000000E-11
#
#   80: CH2 + O -> CH + OH
#       Rate: 4.98e-10*exp(-6000.0*invT)
#
#   81: C2 + O -> CO + C
#       Rate: 2.0e-12/T32**0.12
#
#   82: C2 + O -> CO + C
#       Rate: 2.0e-12*T32**0.757
#
#   83: O + H2 -> OH + H
#       Rate: 1.46e-12*exp(-9650.0*invT)
#
#   84: OH + H -> O + H2
#       Rate: 6.99e-14*T32**2.8*exp(-1950.0*invT)
#
#   85: H2 + OH -> H2O + H
#       Rate: 3.6e-16*T**1.52*exp(-1740.0*invT)
#
#   86: C + OH -> H + CO
#       Rate: 3.68000000000000E-10
#
#   87: C + OH -> H + CO
#       Rate: 2.25e-11*exp(-0.108*invT)/T32**0.339
#
#   88: O + OH -> H + O2
#       Rate: 2.4e-11*exp(-110.0*invT)
#
#   89: O + OH -> H + O2
#       Rate: 2.42000000000000E-12
#
#   90: O + OH -> H + O2
#       Rate: 6.2e-14*T32**2.62*exp(-945.0*invT)
#
#   91: O + OH -> H + O2
#       Rate: 1.38000000000000E-12
#
#   92: OH + OH -> H2O + O
#       Rate: 1.65e-12*T32**1.14*exp(-50.0*invT)
#
#   93: H2O + H -> H2 + OH
#       Rate: 1.59e-11*T32*1.2*exp(-9610.0*invT)
#
#   94: O2 + H -> OH + O
#       Rate: 2.61e-10*1.2*exp(-8156.0*invT)
#
#   95: O2 + H2 -> OH + OH
#       Rate: 3.16e-10*exp(-21890.0*invT)
#
#   96: O2 + C -> CO + O
#       Rate: 4.7e-11/T32**0.34
#
#   97: O2 + C -> CO + O
#       Rate: 2.48e-12*T32**1.54*exp(613.0*invT)
#
#   98: CO + H -> C + OH
#       Rate: 1.1e-10*T32**0.5*exp(-77700.0*invT)
#
#   99: H2+ + H2 -> H3+ + H
#       Rate: 2.24e-9*T32**0.042*exp((-Tgas)/46600.0)
#
#   100: H3+ + H -> H2+ + H2
#       Rate: 7.7e-9*exp(-17560.0*invT)
#
#   101: C + H2+ -> CH+ + H
#       Rate: 2.40000000000000E-9
#
#   102: C + H3+ -> CH+ + H2
#       Rate: (7.2733e-11*sqrt(Tgas) + 5.9203e-14*Tgas + 1.0218e-9)/(Tgas**0.1667 + 0.044914*sqrt(Tgas) - 5.9203e-14*Tgas + 2.6397e-6*Tgas**1.5)
#
#   103: C + H3+ -> CH2+ + H
#       Rate: 8.5145e-10/(Tgas**0.1667 + 0.00095666*sqrt(Tgas) - 4.404e-5*Tgas + 2.3496e-6*Tgas**1.5)
#
#   104: C+ + H2 -> CH+ + H
#       Rate: 1.0e-10*exp(-4640.0*invT)
#
#   105: CH+ + H -> C+ + H2
#       Rate: 7.50000000000000E-10
#
#   106: CH+ + H2 -> CH2+ + H
#       Rate: 1.20000000000000E-9
#
#   107: CH+ + O -> CO+ + H
#       Rate: 3.50000000000000E-10
#
#   108: CH2+ + H -> CH+ + H2
#       Rate: 1.0e-9*exp(-7080.0*invT)
#
#   109: CH2+ + H2 -> CH3+ + H
#       Rate: 1.60000000000000E-9
#
#   110: CH2+ + O -> HCO+ + H
#       Rate: 7.50000000000000E-10
#
#   111: CH3+ + H -> CH2+ + H2
#       Rate: 7.0e-10*exp(-10560.0*invT)
#
#   112: CH3+ + O -> HOC+ + H2
#       Rate: 2.50000000000000E-10
#
#   113: CH3+ + O -> HCO+ + H2
#       Rate: 2.50000000000000E-10
#
#   114: C2 + O+ -> CO+ + C
#       Rate: 4.80000000000000E-10
#
#   115: O+ + H2 -> H + OH+
#       Rate: 1.69000000000000E-9
#
#   116: O + H2+ -> H + OH+
#       Rate: 1.50000000000000E-9
#
#   117: O + H3+ -> H2 + OH+
#       Rate: 7.98e-10*exp(-1.41*invT)/T32**0.156
#
#   118: O + H3+ -> H + H2O+
#       Rate: 3.42e-10*exp(-1.41*invT)/T32**0.156
#
#   119: OH + H3+ -> H2 + H2O+
#       Rate: 2.28000000000000E-8
#
#   120: OH + H3+ -> H2 + H2O+
#       Rate: 1.52e-9*(2.62185*(300.0*invT)**0.5 + 0.62)
#
#   121: OH + C+ -> H + CO+
#       Rate: 2.28000000000000E-8
#
#   122: OH + C+ -> H + CO+
#       Rate: 9.15e-10*(2.62185*(300.0*invT)**0.5 + 0.62)
#
#   123: OH+ + H2 -> H2O+ + H
#       Rate: 1.01000000000000E-9
#
#   124: H2O+ + H2 -> H3O+ + H
#       Rate: 6.40000000000000E-10
#
#   125: H2O + H3+ -> H2 + H3O+
#       Rate: 2.55000000000000E-8
#
#   126: H2O + H3+ -> H2 + H3O+
#       Rate: 1.73e-9*(2.578947*(300.0*invT)**0.5 + 0.62)
#
#   127: H2O + C+ -> HOC+ + H
#       Rate: 1.80000000000000E-9
#
#   128: H2O + C+ -> HCO+ + H
#       Rate: 5.03000000000000E-9
#
#   129: H2O + C+ -> HCO+ + H
#       Rate: 3.4093e-10*(2.578947*(300.0*invT)**0.5 + 0.62)
#
#   130: H2O + C+ -> H2O+ + C
#       Rate: 2.40000000000000E-10
#
#   131: H3O+ + C -> HCO+ + H2
#       Rate: 1.00000000000000E-11
#
#   132: O2 + C+ -> CO+ + O
#       Rate: 3.42000000000000E-10
#
#   133: O2 + C+ -> CO + O+
#       Rate: 4.53000000000000E-10
#
#   134: O2 + CH2+ -> HCO+ + OH
#       Rate: 9.10000000000000E-10
#
#   135: C + O2+ -> O + CO+
#       Rate: 5.20000000000000E-11
#
#   136: C + O2+ -> O2 + C+
#       Rate: 5.20000000000000E-11
#
#   137: CO + H3+ -> H2 + HCO+
#       Rate: 2.47000000000000E-9
#
#   138: CO + H3+ -> H2 + HCO+
#       Rate: 1.88055e-9*(1.79558*invT + 0.02427*(300.0*invT)**0.5 + 1.0)
#
#   139: CO + H3+ -> H2 + HOC+
#       Rate: 1.45000000000000E-10
#
#   140: CO + H3+ -> H2 + HOC+
#       Rate: 1.08256e-10*(1.79558*invT + 0.02427*(300.0*invT)**0.5 + 1.0)
#
#   141: HCO+ + C -> CO + CH+
#       Rate: 1.00000000000000E-9
#
#   142: HCO+ + H2O -> CO + H3O+
#       Rate: 1.23000000000000E-8
#
#   143: HCO+ + H2O -> CO + H3O+
#       Rate: 8.34e-10*(834.16588*invT + 0.5232*(300.0*invT)**0.5 + 1.0)
#
#   144: CH + H+ -> CH+ + H
#       Rate: 3.30000000000000E-8
#
#   145: CH + H+ -> CH+ + H
#       Rate: 3.54e-9*(1.587411*(300.0*invT)**0.5 + 0.62)
#
#   146: CH2 + H+ -> H2 + CH+
#       Rate: 1.765e-9*(0.672147*(300.0*invT)**0.5 + 0.62)
#
#   147: CH2 + H+ -> H2 + CH+
#       Rate: 1.765e-9*(56.66255*invT + 0.136347*(300.0*invT)**0.5 + 1.0)
#
#   148: CH2 + H+ -> H + CH2+
#       Rate: 1.765e-9*(0.672147*(300.0*invT)**0.5 + 0.62)
#
#   149: CH2 + H+ -> H + CH2+
#       Rate: 1.765e-9*(56.66255*invT + 0.136347*(300.0*invT)**0.5 + 1.0)
#
#   150: CH2 + He+ -> He + H2 + C+
#       Rate: 9.65e-10*(0.672147*(300.0*invT)**0.5 + 0.62)
#
#   151: CH2 + He+ -> He + H2 + C+
#       Rate: 9.65e-10*(56.6625498765*invT + 0.136347*(300.0*invT)**0.5 + 1.0)
#
#   152: CH2 + He+ -> He + H + CH+
#       Rate: 9.65e-10*(0.672147*(300.0*invT)**0.5 + 0.62)
#
#   153: CH2 + He+ -> He + H + CH+
#       Rate: 9.65e-10*(56.6625498765*invT + 0.136347*(300.0*invT)**0.5 + 1.0)
#
#   154: C2 + He+ -> C+ + C + He
#       Rate: 1.60000000000000E-9
#
#   155: OH + H+ -> OH+ + H
#       Rate: 3.75000000000000E-8
#
#   156: OH + H+ -> OH+ + H
#       Rate: 2.5e-9*(2.62185*(300.0*invT)**0.5 + 0.62)
#
#   157: OH + He+ -> O+ + He + H
#       Rate: 2.20000000000000E-8
#
#   158: OH + He+ -> O+ + He + H
#       Rate: 1.35e-9*(2.62185*(300.0*invT)**0.5 + 0.62)
#
#   159: H2O + H+ -> H + H2O+
#       Rate: 4.20000000000000E-8
#
#   160: H2O + H+ -> H + H2O+
#       Rate: 2.85e-9*(2.578947*(300.0*invT)**0.5 + 0.62)
#
#   161: H2O + He+ -> He + OH + H+
#       Rate: 7.56000000000000E-9
#
#   162: H2O + He+ -> He + OH + H+
#       Rate: 5.1282e-10*(2.578947*(300.0*invT)**0.5 + 0.62)
#
#   163: H2O + He+ -> He + OH+ + H
#       Rate: 7.56000000000000E-9
#
#   164: H2O + He+ -> He + OH+ + H
#       Rate: 5.1282e-10*(2.578947*(300.0*invT)**0.5 + 0.62)
#
#   165: H2O + He+ -> He + H2O+
#       Rate: 7.56000000000000E-9
#
#   166: H2O + He+ -> He + H2O+
#       Rate: 5.1282e-10*(2.578947*(300.0*invT)**0.5 + 0.62)
#
#   167: O2 + H+ -> O2+ + H
#       Rate: 2.00000000000000E-9
#
#   168: O2 + He+ -> O2+ + He
#       Rate: 3.30000000000000E-11
#
#   169: O2 + He+ -> O+ + He + O
#       Rate: 1.10000000000000E-9
#
#   170: CO + He+ -> C+ + He + O
#       Rate: 1.4e-9/T32**0.5
#
#   171: CO + He+ -> C + He + O+
#       Rate: 1.4e-16/T32**0.5
#
#   172: CO+ + H -> CO + H+
#       Rate: 7.50000000000000E-10
#
#   173: C- + H+ -> C + H
#       Rate: 2.3e-7/T32**0.5
#
#   174: O- + H+ -> O + H
#       Rate: 2.3e-7/T32**0.5
#
#   175: He+ + H- -> H + He
#       Rate: 2.3e-7/T32**0.5
#
#   176: H3+ + e- -> H2 + H
#       Rate: 2.34e-8/T32**0.52
#
#   177: H3+ + e- -> H + H + H
#       Rate: 4.36e-8/T32**0.52
#
#   178: CH+ + e- -> C + H
#       Rate: 7.0e-8/T32**0.5
#
#   179: CH2+ + e- -> CH + H
#       Rate: 1.6e-7/T32**0.6
#
#   180: CH2+ + e- -> C + H2
#       Rate: 7.68e-8/T32**0.6
#
#   181: CH2+ + e- -> C + H + H
#       Rate: 4.03e-7/T32**0.6
#
#   182: CH3+ + e- -> CH2 + H
#       Rate: 7.75e-8/T32**0.5
#
#   183: CH3+ + e- -> CH + H2
#       Rate: 1.95e-7/T32**0.5
#
#   184: CH3+ + e- -> CH + H + H
#       Rate: 2.0e-7/T32**0.5
#
#   185: OH+ + e- -> O + H
#       Rate: 6.3e-9/T32**0.48
#
#   186: H2O+ + e- -> O + H2
#       Rate: 3.9e-8/T32**0.5
#
#   187: H2O+ + e- -> OH + H
#       Rate: 8.6e-8/T32**0.5
#
#   188: H2O+ + e- -> O + H + H
#       Rate: 3.05e-7/T32**0.5
#
#   189: H3O+ + e- -> OH + H + H
#       Rate: 2.58e-7/T32**0.5
#
#   190: H3O+ + e- -> O + H + H2
#       Rate: 5.6e-9/T32**0.5
#
#   191: H3O+ + e- -> H + H2O
#       Rate: 1.08e-7/T32**0.5
#
#   192: H3O+ + e- -> OH + H2
#       Rate: 6.02e-7/T32**0.5
#
#   193: O2+ + e- -> O + O
#       Rate: 1.95e-7/T32**0.7
#
#   194: CO+ + e- -> C + O
#       Rate: 2.75e-7/T32**0.55
#
#   195: HCO+ + e- -> CO + H
#       Rate: 2.76e-7/T32**0.64
#
#   196: HCO+ + e- -> OH + C
#       Rate: 2.4e-8/T32**0.64
#
#   197: HOC+ + e- -> CO + H
#       Rate: 1.1e-7*invT32
#
#   198: H- + C -> CH + e-
#       Rate: 1.00000000000000E-9
#
#   199: H- + O -> OH + e-
#       Rate: 1.00000000000000E-10
#
#   200: H- + OH -> H2O + e-
#       Rate: 5.00000000000000E-10
#
#   201: C- + H -> CH + e-
#       Rate: 1.00000000000000E-13
#
#   202: C- + H2 -> CH2 + e-
#       Rate: 5.00000000000000E-10
#
#   203: C- + O -> CO + e-
#       Rate: 5.00000000000000E-10
#
#   204: O- + H -> OH + e-
#       Rate: 7.00000000000000E-10
#
#   205: O- + H2 -> H2O + e-
#       Rate: 7.00000000000000E-10
#
#   206: O- + C -> CO + e-
#       Rate: 5.00000000000000E-10
#
#   207: H2 + H+ -> H + H2+
#       Rate: 6.4e-10*exp(-21300.0*invT)
#
#   208: H2 + H+ -> H + H + H+
#       Rate: 3.0e-11*T32**0.5*exp(-52000.0*invT)
#
#   209: H2 + H+ -> H3+
#       Rate: 1.00000000000000E-16
#
#   210: C + e- -> C-
#       Rate: 2.25000000000000E-15
#
#   211: C + H -> CH
#       Rate: 1.00000000000000E-17
#
#   212: C + H2 -> CH2
#       Rate: 1.00000000000000E-17
#
#   213: C + C -> C2
#       Rate: 4.36e-18*T32**0.35*exp(-161.3*invT)
#
#   214: C + O -> CO
#       Rate: 1.00000000000000E-19
#
#   215: C + O -> CO
#       Rate: 3.09e-17*T32**0.33*exp(-1629.0*invT)
#
#   216: C+ + H -> CH+
#       Rate: 4.46e-16*exp(-4.93/Tgas**0.6667)/Tgas**0.5
#
#   217: C+ + H2 -> CH2+
#       Rate: 2.0e-16*exp(-23.0*invTgas)/T32**1.3
#
#   218: C+ + O -> CO+
#       Rate: 2.50000000000000E-18
#
#   219: C+ + O -> CO+
#       Rate: 3.14e-18*exp(-68.0*invT)/T32**0.15
#
#   220: O + e- -> O-
#       Rate: 1.50000000000000E-15
#
#   221: O + H -> OH
#       Rate: 9.9e-19/T32**0.38
#
#   222: O + O -> O2
#       Rate: 4.9e-20*T32**1.58
#
#   223: OH + H -> H2O
#       Rate: 5.26e-18*exp(-90.0*invT)/T32**5.22
#
#   224: H + H -> H2
#       Rate: 3.0e-18*Hnuclei*sqrt(Tgas)*fA/((8.0e-6*Tgas**2 + 0.002*Tgas + 0.04*sqrt(Tgas + user_Tdust) + 1.0)*n(idx_H))
#
#   225: H- -> H + e-
#       Rate: 7.1e-7*exp(-0.5*user_Av)
#
#   226: H2+ -> H + H+
#       Rate: 1.1e-9*exp(-1.9*user_Av)
#
#   227: H2 -> H + H
#       Rate: 5.6e-11*user_H2self*exp(-3.74*user_Av)
#
#   228: H3+ -> H2 + H+
#       Rate: 4.9e-13*exp(-1.8*user_Av)
#
#   229: H3+ -> H2+ + H
#       Rate: 4.9e-13*exp(-2.3*user_Av)
#
#   230: C -> C+ + e-
#       Rate: 3.1e-10*exp(-3.0*user_Av)
#
#   231: C- -> C + e-
#       Rate: 2.4e-7*exp(-0.9*user_Av)
#
#   232: CH -> C + H
#       Rate: 8.7e-10*exp(-1.2*user_Av)
#
#   233: CH -> CH+ + e-
#       Rate: 7.7e-10*exp(-2.8*user_Av)
#
#   234: CH+ -> C + H+
#       Rate: 2.6e-10*exp(-2.5*user_Av)
#
#   235: CH2 -> CH + H
#       Rate: 7.1e-10*exp(-1.7*user_Av)
#
#   236: CH2 -> CH2+ + e-
#       Rate: 5.9e-10*exp(-2.3*user_Av)
#
#   237: CH2+ -> CH+ + H
#       Rate: 4.6e-10*exp(-1.7*user_Av)
#
#   238: CH3+ -> CH2+ + H
#       Rate: 1.0e-9*exp(-1.7*user_Av)
#
#   239: CH3+ -> CH+ + H2
#       Rate: 1.0e-9*exp(-1.7*user_Av)
#
#   240: C2 -> C + C
#       Rate: 1.5e-10*exp(-2.1*user_Av)
#
#   241: O- -> O + e-
#       Rate: 2.4e-7*exp(-0.5*user_Av)
#
#   242: OH -> O + H
#       Rate: 3.7e-10*exp(-1.7*user_Av)
#
#   243: OH -> OH+ + e-
#       Rate: 1.6e-12*exp(-3.1*user_Av)
#
#   244: OH+ -> O + H+
#       Rate: 1.0e-12*exp(-1.8*user_Av)
#
#   245: H2O -> OH + H
#       Rate: 6.0e-10*exp(-1.7*user_Av)
#
#   246: H2O -> H2O+ + e-
#       Rate: 3.2e-11*exp(-3.9*user_Av)
#
#   247: H2O+ -> H2+ + O
#       Rate: 5.0e-11*HnOj
#
#   248: H2O+ -> H+ + OH
#       Rate: 5.0e-11*HnOj
#
#   249: H2O+ -> O+ + H2
#       Rate: 5.0e-11*HnOj
#
#   250: H2O+ -> OH+ + H
#       Rate: 1.5e-10*HnOj
#
#   251: H3O+ -> H+ + H2O
#       Rate: 2.5e-11*HnOj
#
#   252: H3O+ -> H2+ + OH
#       Rate: 2.5e-11*HnOj
#
#   253: H3O+ -> H2O+ + H
#       Rate: 7.5e-12*HnOj
#
#   254: H3O+ -> OH+ + H2
#       Rate: 2.5e-11*HnOj
#
#   255: O2 -> O2+ + e-
#       Rate: 5.6e-11*exp(-3.7*user_Av)
#
#   256: O2 -> O + O
#       Rate: 7.0e-10*exp(-1.8*user_Av)
#
#   257: CO -> C + O
#       Rate: 2.0e-10*exp(-3.53*user_Av)
#
#   258: H -> H+ + e-
#       Rate: 0.46*crate
#
#   259: He -> He+ + e-
#       Rate: 0.5*crate
#
#   260: O -> O+ + e-
#       Rate: 2.8*crate
#
#   261: CO -> C + O
#       Rate: 5.0*crate
#
#   262: CO -> CO+ + e-
#       Rate: 3.0*crate
#
#   263: C2 -> C + C
#       Rate: 237.0*crate
#
#   264: H2 -> H + H
#       Rate: 0.1*crate
#
#   265: H2 -> H+ + H-
#       Rate: 0.0003*crate
#
#   266: H2 -> H2+ + e-
#       Rate: 0.93*crate
#
#   267: C -> C+ + e-
#       Rate: 1020.0*crate
#
#   268: CH -> C + H
#       Rate: 730.0*crate
#
#   269: O2 -> O + O
#       Rate: 750.0*crate
#
#   270: O2 -> O2+ + e-
#       Rate: 117.0*crate
#
#   271: OH -> O + H
#       Rate: 510.0*crate
#
#   272: CH2 -> CH2+ + e-
#       Rate: 500.0*crate
#
#   273: H2O -> OH + H
#       Rate: 970.0*crate
#
#   274: HCO -> CO + H
#       Rate: 421.0*crate
#
#   275: HCO -> HCO+ + e-
#       Rate: 1170.0*crate
#
#   276: H2 -> H + H+ + e-
#       Rate: 0.93*crate
#
#   277: C + C -> C2
#       Rate: 5.99e-33*ntot/(Tgas/5000.0)**1.6
#
#   278: C + C -> C2
#       Rate: 5.99e-33*ntot*exp(5255.0/Tgas)/(Tgas/5000.0)**0.64
#
#   279: C + O -> CO
#       Rate: 6.16e-29*ntot/(Tgas/300.0)**3.08
#
#   280: C + O -> CO
#       Rate: 2.14e-29*ntot*exp(2114.0/Tgas)/(Tgas/300.0)**3.08
#
#   281: C+ + O -> CO+
#       Rate: 6.16e-27*ntot/(Tgas/300.0)**3.08
#
#   282: C+ + O -> CO+
#       Rate: 2.14e-27*ntot*exp(2114.0/Tgas)/(Tgas/300.0)**3.08
#
#   283: C + O+ -> CO+
#       Rate: 6.16e-27*ntot/(Tgas/300.0)**3.08
#
#   284: C + O+ -> CO+
#       Rate: 2.14e-27*ntot*exp(2114.0/Tgas)/(Tgas/300.0)**3.08
#
#   285: H + O -> OH
#       Rate: 4.33e-32*ntot/T32
#
#   286: OH + H -> H2O
#       Rate: 2.56e-31*ntot/T32**2
#
#   287: O + O -> O2
#       Rate: 9.2e-34*ntot/T32

# %% [markdown]
# ## Step 3: Generate C++ Kokkos Code
#
# Now let's use the Builder to generate C++ code using the `kokkos_ode` template.

# %%
# Create builder and generate Kokkos C++ code
builder = Builder(network)
builds_dir = builder.build(template="kokkos_ode")

print("\nC++ Kokkos code generated successfully!")
print(f"Generated files are located at {builds_dir}")
# Out:
# Building network with template: kokkos_ode
# Preprocessing /Users/benwibking/amrex_codes/chemistry/jaff/src/jaff/templates/kokkos_ode/chemistry_ode.hpp -> /Users/benwibking/amrex_codes/chemistry/jaff/examples/chemistry_ode.hpp
# Preprocessing /Users/benwibking/amrex_codes/chemistry/jaff/src/jaff/templates/kokkos_ode/chemistry_ode.cpp -> /Users/benwibking/amrex_codes/chemistry/jaff/examples/chemistry_ode.cpp
# Preprocessing /Users/benwibking/amrex_codes/chemistry/jaff/src/jaff/templates/kokkos_ode/CMakeLists.txt -> /Users/benwibking/amrex_codes/chemistry/jaff/examples/CMakeLists.txt
# Network built successfully using template 'kokkos_ode'.
# Output files are located in: /Users/benwibking/amrex_codes/chemistry/jaff/examples
#
# C++ Kokkos code generated successfully!
# Generated files are located at /Users/benwibking/amrex_codes/chemistry/jaff/examples

# %% [markdown]
# ## Step 4: Examine Generated Files
#
# Let's look at the structure and content of the generated files.

# %%
# List generated files
generated_files = [f for f in os.listdir(builds_dir) if f.endswith(('.cpp', '.hpp', '.txt'))]

print("Generated files:")
for file in sorted(generated_files):
    filepath = os.path.join(builds_dir, file)
    size = os.path.getsize(filepath)
    print(f"  {file:20} ({size:,} bytes)")
# Out:
# Generated files:
#   CMakeLists.txt       (1,309 bytes)
#   chemistry_ode.cpp    (6,000 bytes)
#   chemistry_ode.hpp    (165,006 bytes)

# %% [markdown]
# ## Step 5: Understanding the Generated Code Structure
#
# Let's examine key components of the generated chemistry solver.

# %%
# Show the ChemistryODE class definition
with open(builds_dir + "/chemistry_ode.hpp", 'r') as f:
    lines = f.readlines()

# Find the class definition
class_start = None
for i, line in enumerate(lines):
    if "struct ChemistryODE" in line:
        class_start = i
        break

if class_start:
    print("ChemistryODE class structure:")
    print("=" * 50)
    # Show class definition and methods
    brace_count = 0
    for i in range(class_start, len(lines)):
        line = lines[i].rstrip()
        print(f"{i+1:2d}: {line}")
        
        if '{' in line:
            brace_count += line.count('{')
        if '}' in line:
            brace_count -= line.count('}')
            if brace_count == 0:
                break
# Out:
# ChemistryODE class structure:
# ==================================================
# 13: struct ChemistryODE {
# 14:     // Number of species in the chemical network
# 15:     // PREPROCESS_NUM_SPECIES
# 16:
# 17:     static constexpr int neqs = 37;
# 18:
# 19:     // PREPROCESS_END
# 20:
# 21:     // Species indices
# 22:     // PREPROCESS_COMMONS
# 23:
# 24:     static constexpr int idx_H = 0;
# 25:     static constexpr int idx_e = 1;
# 26:     static constexpr int idx_Hj = 2;
# 27:     static constexpr int idx_He = 3;
# 28:     static constexpr int idx_Hej = 4;
# 29:     static constexpr int idx_Hejj = 5;
# 30:     static constexpr int idx_H2 = 6;
# 31:     static constexpr int idx_H2j = 7;
# 32:     static constexpr int idx_Hk = 8;
# 33:     static constexpr int idx_Cj = 9;
# 34:     static constexpr int idx_C = 10;
# 35:     static constexpr int idx_Sij = 11;
# 36:     static constexpr int idx_Si = 12;
# 37:     static constexpr int idx_Oj = 13;
# 38:     static constexpr int idx_O = 14;
# 39:     static constexpr int idx_Sijj = 15;
# 40:     static constexpr int idx_OH = 16;
# 41:     static constexpr int idx_HOCj = 17;
# 42:     static constexpr int idx_HCOj = 18;
# 43:     static constexpr int idx_CO = 19;
# 44:     static constexpr int idx_CH = 20;
# 45:     static constexpr int idx_CH2 = 21;
# 46:     static constexpr int idx_C2 = 22;
# 47:     static constexpr int idx_HCO = 23;
# 48:     static constexpr int idx_H2O = 24;
# 49:     static constexpr int idx_O2 = 25;
# 50:     static constexpr int idx_H3j = 26;
# 51:     static constexpr int idx_CHj = 27;
# 52:     static constexpr int idx_CH2j = 28;
# 53:     static constexpr int idx_COj = 29;
# 54:     static constexpr int idx_CH3j = 30;
# 55:     static constexpr int idx_OHj = 31;
# 56:     static constexpr int idx_H2Oj = 32;
# 57:     static constexpr int idx_H3Oj = 33;
# 58:     static constexpr int idx_O2j = 34;
# 59:     static constexpr int idx_Ck = 35;
# 60:     static constexpr int idx_Ok = 36;
# 61:     static constexpr int nspecs = 37;
# 62:     static constexpr int nreactions = 287;
# 63:
# 64:     // Common chemistry variables used in rate expressions
# 65:     // These should typically be passed as parameters or computed from the state
# 66:     static constexpr double DEFAULT_TEMPERATURE = 300.0;  // Default gas temperature in K
# 67:     static constexpr double DEFAULT_AV = 1.0;             // Default visual extinction
# 68:     static constexpr double DEFAULT_CRATE = 1.3e-17;      // Default cosmic ray ionization rate
# 69:
# 70:     // Placeholder function for photorates (should be replaced with actual implementation)
# 71:     template<typename T>
# 72:     KOKKOS_INLINE_FUNCTION
# 73:     static double photorates(int /*index*/, T /*energy*/, T /*max_energy*/) {
# 74:         // Placeholder: return 0 for photochemistry rates
# 75:         // In a real implementation, this would compute photo-dissociation/ionization rates
# 76:         return 0.0;
# 77:     }
# 78:
# 79:     // PREPROCESS_END
# 80:
# 81:     ChemistryODE() {}
# 82:
# 83:     // Evaluate the ODE right-hand side: dy/dt = f(t, y)
# 84:     template <class vec_type1, class vec_type2>
# 85:     KOKKOS_FUNCTION void evaluate_function(const double /*t*/, const double /*dt*/,
# 86:                                           const vec_type1& y, const vec_type2& f) const {
# 87:         // PREPROCESS_TEMP_VARS
# 88:
# 89:         // Temperature and environment variables used in chemical reactions
# 90:         // T is expected to be passed as a parameter or computed from the state
# 91:         const double Tgas = DEFAULT_TEMPERATURE;  // Gas temperature (matches network conventions)
# 92:         const double tgas = Tgas;  // Lowercase alias for compatibility
# 93:
# 94:         // Environmental parameters (should be passed in or use defaults)
# 95:         const double av = DEFAULT_AV;  // Visual extinction
# 96:         const double crate = DEFAULT_CRATE;  // Cosmic ray ionization rate
# 97:
# 98:         // Access to species densities (for compatibility with different conventions)
# 99:         const auto& n = y;  // Species array alias
# 100:
# 101:         // PREPROCESS_END
# 102:
# 103:         // Compute reaction rates
# 104:         // PREPROCESS_NUM_REACTIONS
# 105:
# 106:         double k[287];
# 107:
# 108:         // PREPROCESS_END
# 109:
# 110:         // PREPROCESS_RATES
# 111:
# 112:         // Common subexpressions
# 113:         const double x0 = Kokkos::pow(lnTe, 2);
# 114:         const double x1 = Kokkos::pow(lnTe, 3);
# 115:         const double x2 = Kokkos::pow(lnTe, 4);
# 116:         const double x3 = Kokkos::pow(lnTe, 5);
# 117:         const double x4 = Kokkos::pow(lnTe, 6);
# 118:         const double x5 = Kokkos::pow(lnTe, 7);
# 119:         const double x6 = Kokkos::pow(lnTe, 8);
# 120:         const double x7 = 3.92e-13*Kokkos::pow(invTe, 0.63529999999999998);
# 121:         const double x8 = Kokkos::pow(lnTe, 9);
# 122:         const double x9 = log10(tgas);
# 123:         const double x10 = 1.0/tgas;
# 124:         const double x11 = /* Not supported in C++: */
# 125:         /* get_hnuclei */
# 126:         get_hnuclei(n);
# 127:         const double x12 = 1.0/(x11/(Kokkos::pow(10.0, 5.2041483199999998 - 6.247416000000001e-5*tgas) + 9.9999999999999993e-41) + 1.0);
# 128:         const double x13 = 3.0e-11*Kokkos::exp(-52000.0*invT);
# 129:         const double x14 = 1.7793594306049821e-5*Tgas;
# 130:         const double x15 = Kokkos::sqrt(Tgas);
# 131:         const double x16 = Kokkos::pow(Tgas, -0.40000000000000002);
# 132:         const double x17 = Kokkos::sqrt(invT);
# 133:         const double x18 = log10(0.0001*tgas);
# 134:         const double x19 = 1.0/(x11/(Kokkos::pow(10.0, 1.6200000000000001*Kokkos::pow(x18, 2) - 1.3*x18 + 4.8449999999999998) + 9.9999999999999993e-41) + 1.0);
# 135:         const double x20 = Kokkos::pow(T32, -0.38);
# 136:         const double x21 = 1.0/T32;
# 137:         const double x22 = Kokkos::pow(T32, -0.59999999999999998);
# 138:         const double x23 = Kokkos::pow(T32, -0.55000000000000004);
# 139:         const double x24 = Kokkos::pow(Tgas, -0.64000000000000001);
# 140:         const double x25 = Kokkos::pow(Tgas, 1.5);
# 141:         const double x26 = Kokkos::max(2.73, Kokkos::min(100000000.0, tgas));
# 142:         const double x27 = Kokkos::pow(x26, -0.25);
# 143:         const double x28 = 1.0/x26;
# 144:         const double x29 = 130666.72639118577*x28;
# 145:         const double x30 = 95156.941066405256*x28;
# 146:         const double x31 = 157821.26811013557*x28;
# 147:         const double x32 = Kokkos::pow(Tgas, 0.23999999999999999)*(3.1699999999999999*Kokkos::exp(4.1839999999999999e-7*Tgas) + 1.0);
# 148:         const double x33 = Kokkos::exp(-270.0*invT);
# 149:         const double x34 = Kokkos::sqrt(T32);
# 150:         const double x35 = 5.9203000000000005e-14*Tgas;
# 151:         const double x36 = Kokkos::sqrt(Tgas);
# 152:         const double x37 = Kokkos::pow(Tgas, 0.16669999999999999);
# 153:         const double x38 = Kokkos::pow(T32, -0.156)*Kokkos::exp(-1.4099999999999999*invT);
# 154:         const double x39 = Kokkos::sqrt(invT);
# 155:         const double x40 = 2.0548002110835724e-8*x39 + 1.0943e-9;
# 156:         const double x41 = 1.0000940075e-7*invT + 4.1682227902618297e-9*x39 + 1.765e-9;
# 157:         const double x42 = 1.1234460077595736e-8*x39 + 5.9830000000000009e-10;
# 158:         const double x43 = 5.4679360630822505e-8*invT + 2.2789433385850798e-9*x39 + 9.6500000000000008e-10;
# 159:         const double x44 = 2.2906988549538973e-8*x39 + 3.1794839999999998e-10;
# 160:         const double x45 = 1.0/x34;
# 161:         const double x46 = 2.2999999999999999e-7*x45;
# 162:         const double x47 = Kokkos::pow(T32, -0.52000000000000002);
# 163:         const double x48 = Kokkos::pow(T32, -0.64000000000000001);
# 164:         const double x49 = Kokkos::exp(-0.5*user_Av);
# 165:         const double x50 = Kokkos::exp(-1.8*user_Av);
# 166:         const double x51 = Kokkos::exp(-2.2999999999999998*user_Av);
# 167:         const double x52 = Kokkos::exp(-1.7*user_Av);
# 168:         const double x53 = 1.0000000000000001e-9*x52;
# 169:         const double x54 = 5.0000000000000002e-11*HnOj;
# 170:         const double x55 = 2.5000000000000001e-11*HnOj;
# 171:         const double x56 = 0.93000000000000005*crate;
# 172:         const double x57 = 1.0/Tgas;
# 173:         const double x58 = Kokkos::pow(Tgas, -3.0800000000000001)*ntot;
# 174:         const double x59 = x58*Kokkos::exp(2114.0*x57);
# 175:         const double x60 = 2.6249085452559344e-19*x58;
# 176:         const double x61 = 9.1190004656618504e-20*x59;
# 177:         const double x62 = ntot/T32;
# 178:
# 179:         // Rate calculations using common subexpressions
# 180:         k[0] = 6.2016075140890556e-15*Kokkos::exp(13.536555999999999*lnTe - 5.7393287500000003*x0 + 1.56315498*x1 - 0.28770560000000001*x2 + 0.034825597700000002*x3 - 0.00263197617*x4 + 0.000111954395*x5 - 2.0391498499999999e-6*x6);
# 181:         k[1] = x7;
# 182:         k[2] = 3.745564732629339e-13*Kokkos::exp(-0.7241125657826851*lnTe - 0.02026044731984691*x0 - 0.002380861877349834*x1 - 0.0003212605213188796*x2 - 1.421502914054107e-5*x3 + 4.989108920299513e-6*x4 + 5.755614137575758e-7*x5 - 1.856767039775261e-8*x6 - 3.071135243196595e-9*x8);
# 183:         k[3] = 7.0501789528211863e-20*Kokkos::exp(23.915965629999999*lnTe - 10.753230200000001*x0 + 3.0580387500000001*x1 - 0.56851189000000002*x2 + 0.067953912300000002*x3 - 0.0050090561*x4 + 0.000206723616*x5 - 3.6491614100000001e-6*x6);
# 184:         k[4] = x7;
# 185:         k[5] = 1.5400000000000001e-9*Kokkos::pow(Te, -1.5)*(1.0 + 0.29999999999999999*Kokkos::exp(-8.0993287896670001*invTe))*Kokkos::exp(-40.49664394833662*invTe) + 3.92e-13*Kokkos::pow(Te, -0.63529999999999998);
# 186:         k[6] = 1.4436041776615438e-30*Kokkos::exp(43.933476326349997*lnTe - 18.480669935680002*x0 + 4.701626486759002*x1 - 0.76924663344919997*x2 + 0.081130420973029999*x3 - 0.005324020628287001*x4 + 0.00019757053122209999*x5 - 3.1655810656650001e-6*x6);
# 187:         k[7] = 1.25e-15*Kokkos::pow(T32, 0.25);
# 188:         k[8] = 1.26e-9*Kokkos::pow(Tgas, -0.75)*Kokkos::exp(-127500.0*invT);
# 189:         k[9] = 4.0000000000000003e-37*Kokkos::pow(Tgas, 4.7400000000000002);
# 190:         k[10] = Kokkos::pow(Kokkos::pow(10.0, -29487.0*x10 + 3.8010000000000002*x9 - 27.029), x12)*Kokkos::pow(Kokkos::pow(10.0, -23474.0*x10 - 1.75*x9 - 2.7290000000000001), 1.0 - x12);
# 191:         k[11] = 7.2000000000000002e-15;
# 192:         k[12] = 3.7e-14*Kokkos::exp(35.0*invT);
# 193:         k[13] = Kokkos::sqrt(T32)*x13;
# 194:         k[14] = 1.3376400930597507e-9*Kokkos::pow(Tgas, -0.20000000000000001)/(sqrTgas*(6.3095734448019361e-5*Kokkos::pow(Tgas, 0.69999999999999996) + 1.0));
# 195:         k[15] = 6.77e-15*Kokkos::pow(Te, 0.87790000000000001);
# 196:         k[16] = 1.43e-9;
# 197:         k[17] = 1.9234623341343655e-9*Kokkos::exp(0.2289800603272916*lnTe + 0.03599837721023835*x0 - 0.0045551200270320949*x1 - 0.0003105115447124016*x2 + 0.0001073294010367247*x3 - 8.3667196046786397e-6*x4 + 2.238306228891639e-7*x5);
# 198:         k[18] = 1.8500000000000001e-23*Kokkos::pow(Tgas, 1.8);
# 199:         k[19] = 5.8099999999999997e-16*Kokkos::pow(x14, -0.66569999999999996*log10(x14));
# 200:         k[20] = 6.0e-10;
# 201:         k[21] = 2.9425870565239972e-11*Kokkos::exp(3.400824447095291*lnTe - 3.898003964650152*x0 + 2.045587822403071*x1 - 0.5416182856220388*x2 + 0.084107750376341203*x3 - 0.007879026154483455*x4 + 0.0004138398421504563*x5 - 9.3634588892861096e-6*x6);
# 202:         k[22] = 5.6e-11*x15*Kokkos::exp(-102124.0*invT);
# 203:         k[23] = 1.0670825e-10*Kokkos::pow(Te, 2.012)*Kokkos::pow(0.2472*Te + 1.0, -3.512)*Kokkos::exp(-4.4630000000000001*invTe);
# 204:         k[24] = 1.4950914883969339e-8*Kokkos::exp(2.360852208681*lnTe - 0.28274430617039997*x0 + 0.01623316639567*x1 - 0.03365012031362999*x2 + 0.01178329782711*x3 - 0.001656194699504*x4 + 0.0001068275202678*x5 - 2.6312858092069998e-6*x6);
# 205:         k[25] = 2.5599999999999998e-9*Kokkos::pow(Te, 1.78186);
# 206:         k[26] = 1.4200000000000025e-9*Kokkos::exp(1.139449335841631*lnTe - 0.1421013521554148*x0 + 0.0084644553866299998*x1 - 0.0014327641212992001*x2 + 0.00020122502847909999*x3 + 8.6639632430900003e-5*x4 - 2.5850096802639999e-5*x5 + 2.4555011970391999e-6*x6 - 8.0683824611800006e-8*x8);
# 207:         k[27] = 6.5000000000000003e-9/Kokkos::sqrt(Te);
# 208:         k[28] = 1.0e-8*x16;
# 209:         k[29] = 1.0e-8;
# 210:         k[30] = 1.3200000000000001e-6*Kokkos::pow(Tgas, -0.76000000000000001);
# 211:         k[31] = 4.9999999999999996e-6*x17;
# 212:         k[32] = Kokkos::pow(1.1800000000000001e-10*Kokkos::exp(-69500.0*x10), x19)*Kokkos::pow(8.1250000000000003e-8*(1.0 - Kokkos::exp(-6000.0*x10))*Kokkos::exp(-52000.0*x10)/Kokkos::sqrt(tgas), 1.0 - x19);
# 213:         k[33] = 6.9000000000000002e-32*x16;
# 214:         k[34] = 1.2999999999999999e-32*x20;
# 215:         k[35] = 1.2999999999999999e-32*x21;
# 216:         k[36] = 1.6249999999999998e-33*x20;
# 217:         k[37] = 1.6249999999999998e-33*x21;
# 218:         k[38] = 4.6700000000000001e-12*x22;
# 219:         k[39] = 1.2299999999999999e-17*Kokkos::pow(T32, 2.4900000000000002)*Kokkos::exp(21845.599999999999*invT);
# 220:         k[40] = 9.6200000000000001e-8*Kokkos::pow(T32, -1.3700000000000001)*Kokkos::exp(-115786.2*invT);
# 221:         k[41] = 7.5e-12*x23;
# 222:         k[42] = 4.8599999999999999e-12*Kokkos::pow(T32, -0.32000000000000001);
# 223:         k[43] = 1.2999999999999999e-10*x24;
# 224:         k[44] = 1.41e-10*Kokkos::pow(Tgas, -0.66000000000000003) + 0.00073999999999999999*(1.0 + 0.062*Kokkos::exp(-145000.0*invT))*Kokkos::exp(-175000.0*invT)/x25;
# 225:         k[45] = 1.3023623244766063e-6*x27*Kokkos::exp(-x29)/(x29 + 0.193);
# 226:         k[46] = 3.3019308008249855e-6*x27*(308.47518711624969*Kokkos::pow(x26, -0.5) + 1.0)*Kokkos::exp(-x30)/(x30 + 0.376);
# 227:         k[47] = 2.1012161411986507e-6*Kokkos::pow(x26, -0.34000000000000002)*Kokkos::exp(-x31)/(x31 + 0.072999999999999995);
# 228:         k[48] = 4.9899999999999997e-11*Kokkos::pow(Tgas, 0.40500000000000003) + 7.5399999999999998e-10*Kokkos::pow(invT, 0.45800000000000002);
# 229:         k[49] = (4.0000000000000001e-10*Kokkos::pow(Tgas, 0.0066899999999999998) + 1.0799999999999999e-11*Kokkos::pow(Tgas, 0.51700000000000002))*Kokkos::exp(-227.0*invT);
# 230:         k[50] = 2.038190607495647e-14*Kokkos::pow(Tgas, -0.21629999999999999)*Kokkos::exp(-1.2258e-6*Tgas) + 1.5156103761232729e-16*Kokkos::pow(Tgas, 0.37940000000000002)*Kokkos::exp(-8.9205999999999996e-7*Tgas);
# 231:         k[51] = 3.8999999999999998e-16*Kokkos::pow(Tgas, 0.21299999999999999);
# 232:         k[52] = 8.7882738061352424e-22*Kokkos::pow(Tgas, 1.96)*Kokkos::exp(-170000.0*invT);
# 233:         k[53] = 8.5799999999999996e-17*Kokkos::pow(Tgas, 0.75700000000000001);
# 234:         k[54] = 3.2499999999999998e-17*Kokkos::pow(Tgas, 0.96799999999999997);
# 235:         k[55] = 2.77e-19*Kokkos::pow(Tgas, 1.597);
# 236:         k[56] = 5.8800000000000002e-13*Kokkos::pow(Tgas, 0.84799999999999998);
# 237:         k[57] = 1.4499999999999999e-13*Tgas;
# 238:         k[58] = 3.3000000000000002e-9;
# 239:         k[59] = 2.1000000000000002e-9;
# 240:         k[60] = 4.4955606041870586e-11*x32*Kokkos::exp(-3.1779999999999999*invTe);
# 241:         k[61] = 1.3486681812561178e-10*x32;
# 242:         k[62] = 6.0455810608518555e-10*Kokkos::pow(Tgas, -0.63460000000000005);
# 243:         k[63] = 6.0e-9*Kokkos::exp(-50900.0*invT);
# 244:         k[64] = 3.0e-10;
# 245:         k[65] = 1.14e-9;
# 246:         k[66] = 6.2094116000000001e-9*invT + 3.6490561664708348e-10*x17 + 8.68e-10;
# 247:         k[67] = 6.6399999999999998e-10*Kokkos::exp(-11700.0*invT);
# 248:         k[68] = 1.3100000000000001e-10*Kokkos::exp(-80.0*invT);
# 249:         k[69] = 5.4599999999999998e-10*Kokkos::exp(-1943.0*invT);
# 250:         k[70] = 2.4e-10;
# 251:         k[71] = 6.6000000000000005e-11;
# 252:         k[72] = 1.02e-10*Kokkos::exp(-914.0*invT);
# 253:         k[73] = 1.8999999999999999e-11*Kokkos::pow(T32, -2.2000000000000002)*Kokkos::exp(-165.09999999999999*invT);
# 254:         k[74] = 2.5200000000000001e-11*Kokkos::exp(-2381.0*invT);
# 255:         k[75] = 2.1999999999999999e-10;
# 256:         k[76] = 2.0399999999999999e-10*x33;
# 257:         k[77] = 1.36e-10*x33;
# 258:         k[78] = 5.01e-11;
# 259:         k[79] = 4.9800000000000004e-10*Kokkos::exp(-6000.0*invT);
# 260:         k[80] = 2.0e-12*Kokkos::pow(T32, -0.12);
# 261:         k[81] = 2.0e-12*Kokkos::pow(T32, 0.75700000000000001);
# 262:         k[82] = 1.46e-12*Kokkos::exp(-9650.0*invT);
# 263:         k[83] = 6.9899999999999998e-14*Kokkos::pow(T32, 2.7999999999999998)*Kokkos::exp(-1950.0*invT);
# 264:         k[84] = 3.5999999999999998e-16*Kokkos::pow(T, 1.52)*Kokkos::exp(-1740.0*invT);
# 265:         k[85] = 3.6800000000000002e-10;
# 266:         k[86] = 2.25e-11*Kokkos::pow(T32, -0.33900000000000002)*Kokkos::exp(-0.108*invT);
# 267:         k[87] = 2.4000000000000001e-11*Kokkos::exp(-110.0*invT);
# 268:         k[88] = 2.4200000000000002e-12;
# 269:         k[89] = 6.2000000000000001e-14*Kokkos::pow(T32, 2.6200000000000001)*Kokkos::exp(-945.0*invT);
# 270:         k[90] = 1.38e-12;
# 271:         k[91] = 1.65e-12*Kokkos::pow(T32, 1.1399999999999999)*Kokkos::exp(-50.0*invT);
# 272:         k[92] = 1.908e-11*T32*Kokkos::exp(-9610.0*invT);
# 273:         k[93] = 3.1319999999999996e-10*Kokkos::exp(-8156.0*invT);
# 274:         k[94] = 3.1599999999999999e-10*Kokkos::exp(-21890.0*invT);
# 275:         k[95] = 4.6999999999999999e-11*Kokkos::pow(T32, -0.34000000000000002);
# 276:         k[96] = 2.4799999999999999e-12*Kokkos::pow(T32, 1.54)*Kokkos::exp(613.0*invT);
# 277:         k[97] = 1.0999999999999999e-10*x34*Kokkos::exp(-77700.0*invT);
# 278:         k[98] = 2.2400000000000001e-9*Kokkos::pow(T32, 0.042000000000000003)*Kokkos::exp(-2.145922746781116e-5*Tgas);
# 279:         k[99] = 7.6999999999999995e-9*Kokkos::exp(-17560.0*invT);
# 280:         k[100] = 2.4e-9;
# 281:         k[101] = (x35 + 7.2733000000000004e-11*x36 + 1.0217999999999999e-9)/(2.6396999999999999e-6*x25 - x35 + 0.044914000000000003*x36 + x37);
# 282:         k[102] = 8.5144999999999999e-10/(-4.4039999999999998e-5*Tgas + 2.3495999999999999e-6*x25 + 0.00095666000000000002*x36 + x37);
# 283:         k[103] = 1.0e-10*Kokkos::exp(-4640.0*invT);
# 284:         k[104] = 7.5e-10;
# 285:         k[105] = 1.2e-9;
# 286:         k[106] = 3.4999999999999998e-10;
# 287:         k[107] = 1.0000000000000001e-9*Kokkos::exp(-7080.0*invT);
# 288:         k[108] = 1.6000000000000001e-9;
# 289:         k[109] = 7.5e-10;
# 290:         k[110] = 6.9999999999999996e-10*Kokkos::exp(-10560.0*invT);
# 291:         k[111] = 2.5000000000000002e-10;
# 292:         k[112] = 2.5000000000000002e-10;
# 293:         k[113] = 4.8e-10;
# 294:         k[114] = 1.69e-9;
# 295:         k[115] = 1.5e-9;
# 296:         k[116] = 7.9800000000000004e-10*x38;
# 297:         k[117] = 3.4200000000000001e-10*x38;
# 298:         k[118] = 2.2799999999999999e-8;
# 299:         k[119] = 6.90258966293318e-8*x39 + 9.4239999999999997e-10;
# 300:         k[120] = 2.2799999999999999e-8;
# 301:         k[121] = 4.1551773299893819e-8*x39 + 5.673e-10;
# 302:         k[122] = 1.01e-9;
# 303:         k[123] = 6.3999999999999996e-10;
# 304:         k[124] = 2.55e-8;
# 305:         k[125] = 7.7276803148672875e-8*x39 + 1.0726e-9;
# 306:         k[126] = 1.8e-9;
# 307:         k[127] = 5.0300000000000002e-9;
# 308:         k[128] = 1.522889046096939e-8*x39 + 2.1137659999999997e-10;
# 309:         k[129] = 2.4e-10;
# 310:         k[130] = 9.9999999999999994e-12;
# 311:         k[131] = 3.4200000000000001e-10;
# 312:         k[132] = 4.5299999999999999e-10;
# 313:         k[133] = 9.0999999999999996e-10;
# 314:         k[134] = 5.2000000000000001e-11;
# 315:         k[135] = 5.2000000000000001e-11;
# 316:         k[136] = 2.4699999999999999e-9;
# 317:         k[137] = 3.3766779690000001e-9*invT + 7.9052441707634545e-10*x39 + 1.8805500000000001e-9;
# 318:         k[138] = 1.4499999999999999e-10;
# 319:         k[139] = 1.9438230848e-10*invT + 4.5507437342807608e-11*x39 + 1.08256e-10;
# 320:         k[140] = 1.0000000000000001e-9;
# 321:         k[141] = 1.2299999999999999e-8;
# 322:         k[142] = 6.9569434392000005e-7*invT + 7.5577829142171064e-9*x39 + 8.3400000000000002e-10;
# 323:         k[143] = 3.2999999999999998e-8;
# 324:         k[144] = 9.733146825907767e-8*x39 + 2.1947999999999999e-9;
# 325:         k[145] = x40;
# 326:         k[146] = x41;
# 327:         k[147] = x40;
# 328:         k[148] = x41;
# 329:         k[149] = x42;
# 330:         k[150] = x43;
# 331:         k[151] = x42;
# 332:         k[152] = x43;
# 333:         k[153] = 1.6000000000000001e-9;
# 334:         k[154] = 3.7499999999999998e-8;
# 335:         k[155] = 1.1352943524561152e-7*x39 + 1.55e-9;
# 336:         k[156] = 2.1999999999999998e-8;
# 337:         k[157] = 6.130589503263022e-8*x39 + 8.37e-10;
# 338:         k[158] = 4.1999999999999999e-8;
# 339:         k[159] = 1.2730571616977901e-7*x39 + 1.767e-9;
# 340:         k[160] = 7.5599999999999995e-9;
# 341:         k[161] = x44;
# 342:         k[162] = 7.5599999999999995e-9;
# 343:         k[163] = x44;
# 344:         k[164] = 7.5599999999999995e-9;
# 345:         k[165] = x44;
# 346:         k[166] = 2.0000000000000001e-9;
# 347:         k[167] = 3.3000000000000002e-11;
# 348:         k[168] = 1.0999999999999999e-9;
# 349:         k[169] = 1.3999999999999999e-9*x45;
# 350:         k[170] = 1.4000000000000001e-16*x45;
# 351:         k[171] = 7.5e-10;
# 352:         k[172] = x46;
# 353:         k[173] = x46;
# 354:         k[174] = x46;
# 355:         k[175] = 2.3400000000000001e-8*x47;
# 356:         k[176] = 4.36e-8*x47;
# 357:         k[177] = 7.0000000000000005e-8*x45;
# 358:         k[178] = 1.6e-7*x22;
# 359:         k[179] = 7.6799999999999999e-8*x22;
# 360:         k[180] = 4.03e-7*x22;
# 361:         k[181] = 7.7499999999999999e-8*x45;
# 362:         k[182] = 1.9500000000000001e-7*x45;
# 363:         k[183] = 1.9999999999999999e-7*x45;
# 364:         k[184] = 6.3000000000000002e-9*Kokkos::pow(T32, -0.47999999999999998);
# 365:         k[185] = 3.8999999999999998e-8*x45;
# 366:         k[186] = 8.6000000000000002e-8*x45;
# 367:         k[187] = 3.0499999999999999e-7*x45;
# 368:         k[188] = 2.5800000000000001e-7*x45;
# 369:         k[189] = 5.5999999999999997e-9*x45;
# 370:         k[190] = 1.08e-7*x45;
# 371:         k[191] = 6.0200000000000002e-7*x45;
# 372:         k[192] = 1.9500000000000001e-7*Kokkos::pow(T32, -0.69999999999999996);
# 373:         k[193] = 2.7500000000000001e-7*x23;
# 374:         k[194] = 2.7599999999999998e-7*x48;
# 375:         k[195] = 2.4e-8*x48;
# 376:         k[196] = 1.1000000000000001e-7*invT32;
# 377:         k[197] = 1.0000000000000001e-9;
# 378:         k[198] = 1.0e-10;
# 379:         k[199] = 5.0000000000000003e-10;
# 380:         k[200] = 1.0e-13;
# 381:         k[201] = 5.0000000000000003e-10;
# 382:         k[202] = 5.0000000000000003e-10;
# 383:         k[203] = 6.9999999999999996e-10;
# 384:         k[204] = 6.9999999999999996e-10;
# 385:         k[205] = 5.0000000000000003e-10;
# 386:         k[206] = 6.3999999999999996e-10*Kokkos::exp(-21300.0*invT);
# 387:         k[207] = x13*x34;
# 388:         k[208] = 9.9999999999999998e-17;
# 389:         k[209] = 2.2499999999999999e-15;
# 390:         k[210] = 1.0000000000000001e-17;
# 391:         k[211] = 1.0000000000000001e-17;
# 392:         k[212] = 4.3599999999999999e-18*Kokkos::pow(T32, 0.34999999999999998)*Kokkos::exp(-161.30000000000001*invT);
# 393:         k[213] = 9.9999999999999998e-20;
# 394:         k[214] = 3.09e-17*Kokkos::pow(T32, 0.33000000000000002)*Kokkos::exp(-1629.0*invT);
# 395:         k[215] = 4.4600000000000005e-16*Kokkos::exp(-4.9299999999999997*Kokkos::pow(Tgas, -0.66669999999999996))/x15;
# 396:         k[216] = 2.0e-16*Kokkos::pow(T32, -1.3)*Kokkos::exp(-23.0*invTgas);
# 397:         k[217] = 2.5000000000000002e-18;
# 398:         k[218] = 3.1399999999999999e-18*Kokkos::pow(T32, -0.14999999999999999)*Kokkos::exp(-68.0*invT);
# 399:         k[219] = 1.4999999999999999e-15;
# 400:         k[220] = 9.8999999999999993e-19*x20;
# 401:         k[221] = 4.9000000000000002e-20*Kokkos::pow(T32, 1.5800000000000001);
# 402:         k[222] = 5.2599999999999997e-18*Kokkos::pow(T32, -5.2199999999999998)*Kokkos::exp(-90.0*invT);
# 403:         k[223] = /* Not supported in C++: */
# 404:         /* n */
# 405:         2.9999999999999998e-18*Hnuclei*fA*x36/((7.9999999999999996e-6*Kokkos::pow(Tgas, 2) + 0.002*Tgas + 0.040000000000000001*Kokkos::sqrt(Tgas + user_Tdust) + 1.0)*n(idx_H));
# 406:         k[224] = 7.0999999999999998e-7*x49;
# 407:         k[225] = 1.0999999999999999e-9*Kokkos::exp(-1.8999999999999999*user_Av);
# 408:         k[226] = 5.6e-11*user_H2self*Kokkos::exp(-3.7400000000000002*user_Av);
# 409:         k[227] = 4.9000000000000003e-13*x50;
# 410:         k[228] = 4.9000000000000003e-13*x51;
# 411:         k[229] = 3.1000000000000002e-10*Kokkos::exp(-3.0*user_Av);
# 412:         k[230] = 2.3999999999999998e-7*Kokkos::exp(-0.90000000000000002*user_Av);
# 413:         k[231] = 8.6999999999999999e-10*Kokkos::exp(-1.2*user_Av);
# 414:         k[232] = 7.7000000000000003e-10*Kokkos::exp(-2.7999999999999998*user_Av);
# 415:         k[233] = 2.5999999999999998e-10*Kokkos::exp(-2.5*user_Av);
# 416:         k[234] = 7.1000000000000003e-10*x52;
# 417:         k[235] = 5.9000000000000003e-10*x51;
# 418:         k[236] = 4.6000000000000001e-10*x52;
# 419:         k[237] = x53;
# 420:         k[238] = x53;
# 421:         k[239] = 1.5e-10*Kokkos::exp(-2.1000000000000001*user_Av);
# 422:         k[240] = 2.3999999999999998e-7*x49;
# 423:         k[241] = 3.7000000000000001e-10*x52;
# 424:         k[242] = 1.6e-12*Kokkos::exp(-3.1000000000000001*user_Av);
# 425:         k[243] = 9.9999999999999998e-13*x50;
# 426:         k[244] = 6.0e-10*x52;
# 427:         k[245] = 3.1999999999999999e-11*Kokkos::exp(-3.8999999999999999*user_Av);
# 428:         k[246] = x54;
# 429:         k[247] = x54;
# 430:         k[248] = x54;
# 431:         k[249] = 1.5e-10*HnOj;
# 432:         k[250] = x55;
# 433:         k[251] = x55;
# 434:         k[252] = 7.5e-12*HnOj;
# 435:         k[253] = x55;
# 436:         k[254] = 5.6e-11*Kokkos::exp(-3.7000000000000002*user_Av);
# 437:         k[255] = 6.9999999999999996e-10*x50;
# 438:         k[256] = 2.0000000000000001e-10*Kokkos::exp(-3.5299999999999998*user_Av);
# 439:         k[257] = 0.46000000000000002*crate;
# 440:         k[258] = 0.5*crate;
# 441:         k[259] = 2.7999999999999998*crate;
# 442:         k[260] = 5.0*crate;
# 443:         k[261] = 3.0*crate;
# 444:         k[262] = 237.0*crate;
# 445:         k[263] = 0.10000000000000001*crate;
# 446:         k[264] = 0.00029999999999999997*crate;
# 447:         k[265] = x56;
# 448:         k[266] = 1020.0*crate;
# 449:         k[267] = 730.0*crate;
# 450:         k[268] = 750.0*crate;
# 451:         k[269] = 117.0*crate;
# 452:         k[270] = 510.0*crate;
# 453:         k[271] = 500.0*crate;
# 454:         k[272] = 970.0*crate;
# 455:         k[273] = 421.0*crate;
# 456:         k[274] = 1170.0*crate;
# 457:         k[275] = x56;
# 458:         k[276] = 4.9633948909666331e-27*Kokkos::pow(Tgas, -1.6000000000000001)*ntot;
# 459:         k[277] = 1.3956214160944883e-30*ntot*x24*Kokkos::exp(5255.0*x57);
# 460:         k[278] = 2.6249085452559345e-21*x58;
# 461:         k[279] = 9.1190004656618497e-22*x59;
# 462:         k[280] = x60;
# 463:         k[281] = x61;
# 464:         k[282] = x60;
# 465:         k[283] = x61;
# 466:         k[284] = 4.33e-32*x62;
# 467:         k[285] = 2.5600000000000001e-31*ntot/Kokkos::pow(T32, 2);
# 468:         k[286] = 9.2000000000000004e-34*x62;
# 469:
# 470:         // PREPROCESS_END
# 471:
# 472:         // Compute derivatives for each species
# 473:         // PREPROCESS_ODE
# 474:
# 475:         const double cse0 = k[252]*y[33];
# 476:         const double cse1 = k[31]*y[8];
# 477:         const double cse2 = cse1*y[7];
# 478:         const double cse3 = k[109]*y[28];
# 479:         const double cse4 = cse3*y[14];
# 480:         const double cse5 = k[228]*y[26];
# 481:         const double cse6 = k[234]*y[21];
# 482:         const double cse7 = k[78]*y[21];
# 483:         const double cse8 = cse7*y[14];
# 484:         const double cse9 = k[236]*y[28];
# 485:         const double cse10 = k[100]*y[10];
# 486:         const double cse11 = cse10*y[7];
# 487:         const double cse12 = k[103]*y[9];
# 488:         const double cse13 = cse12*y[6];
# 489:         const double cse14 = k[104]*y[27];
# 490:         const double cse15 = cse14*y[0];
# 491:         const double cse16 = -cse15;
# 492:         const double cse17 = k[275]*y[6];
# 493:         const double cse18 = k[225]*y[7];
# 494:         const double cse19 = std::pow(y[0], 2);
# 495:         const double cse20 = cse19*k[223];
# 496:         const double cse21 = std::pow(y[0], 3);
# 497:         const double cse22 = cse21*k[34];
# 498:         const double cse23 = cse21*k[35];
# 499:         const double cse24 = k[226]*y[6];
# 500:         const double cse25 = k[263]*y[6];
# 501:         const double cse26 = k[32]*std::pow(y[6], 2);
# 502:         const double cse27 = k[108]*y[28];
# 503:         const double cse28 = cse27*y[6];
# 504:         const double cse29 = k[123]*y[32];
# 505:         const double cse30 = cse29*y[6];
# 506:         const double cse31 = k[177]*y[27];
# 507:         const double cse32 = cse31*y[1];
# 508:         const double cse33 = k[178]*y[28];
# 509:         const double cse34 = cse33*y[1];
# 510:         const double cse35 = k[184]*y[31];
# 511:         const double cse36 = cse35*y[1];
# 512:         const double cse37 = k[186]*y[32];
# 513:         const double cse38 = cse37*y[1];
# 514:         const double cse39 = k[98]*y[7];
# 515:         const double cse40 = cse39*y[6];
# 516:         const double cse41 = k[110]*y[30];
# 517:         const double cse42 = cse41*y[0];
# 518:         const double cse43 = k[16]*y[8];
# 519:         const double cse44 = cse43*y[0];
# 520:         const double cse45 = k[17]*y[8];
# 521:         const double cse46 = cse45*y[0];
# 522:         const double cse47 = k[18]*y[2];
# 523:         const double cse48 = cse47*y[0];
# 524:         const double cse49 = k[19]*y[2];
# 525:         const double cse50 = cse49*y[0];
# 526:         const double cse51 = k[215]*y[9];
# 527:         const double cse52 = cse51*y[0];
# 528:         const double cse53 = k[99]*y[26];
# 529:         const double cse54 = cse53*y[0];
# 530:         const double cse55 = cse19*k[33];
# 531:         const double cse56 = cse55*y[3];
# 532:         const double cse57 = cse19*k[36];
# 533:         const double cse58 = cse57*y[6];
# 534:         const double cse59 = cse19*k[37];
# 535:         const double cse60 = cse59*y[6];
# 536:         const double cse61 = k[10]*y[6];
# 537:         const double cse62 = cse61*y[3];
# 538:         const double cse63 = k[13]*y[6];
# 539:         const double cse64 = cse63*y[4];
# 540:         const double cse65 = k[180]*y[28];
# 541:         const double cse66 = cse65*y[1];
# 542:         const double cse67 = k[183]*y[30];
# 543:         const double cse68 = cse67*y[1];
# 544:         const double cse69 = k[187]*y[32];
# 545:         const double cse70 = cse69*y[1];
# 546:         const double cse71 = k[188]*y[33];
# 547:         const double cse72 = cse71*y[1];
# 548:         const double cse73 = k[207]*y[6];
# 549:         const double cse74 = cse73*y[2];
# 550:         const double cse75 = k[22]*y[6];
# 551:         const double cse76 = cse75*y[1];
# 552:         const double cse77 = k[23]*y[6];
# 553:         const double cse78 = cse77*y[0];
# 554:         const double cse79 = k[27]*y[8];
# 555:         const double cse80 = cse79*y[2];
# 556:         const double cse81 = k[29]*y[7];
# 557:         const double cse82 = cse81*y[1];
# 558:         const double cse83 = k[30]*y[7];
# 559:         const double cse84 = cse83*y[1];
# 560:         const double cse85 = k[76]*y[21];
# 561:         const double cse86 = cse85*y[14];
# 562:         const double cse87 = k[176]*y[26];
# 563:         const double cse88 = cse87*y[1];
# 564:         const double cse89 = k[237]*y[30];
# 565:         const double cse90 = k[181]*y[30];
# 566:         const double cse91 = cse90*y[1];
# 567:         const double cse92 = cse89 + cse91;
# 568:         const double cse93 = k[249]*y[32];
# 569:         const double cse94 = k[114]*y[13];
# 570:         const double cse95 = cse94*y[6];
# 571:         const double cse96 = k[115]*y[14];
# 572:         const double cse97 = cse96*y[7];
# 573:         const double cse98 = k[162]*y[24];
# 574:         const double cse99 = k[163]*y[24];
# 575:         const double cse100 = cse98*y[4] + cse99*y[4];
# 576:         const double cse101 = cse100 + cse93 + cse95 + cse97;
# 577:         const double cse102 = k[189]*y[33];
# 578:         const double cse103 = cse102*y[1];
# 579:         const double cse104 = k[190]*y[33];
# 580:         const double cse105 = cse104*y[1];
# 581:         const double cse106 = cse103 + cse105;
# 582:         const double cse107 = k[224]*y[8];
# 583:         const double cse108 = k[174]*y[8];
# 584:         const double cse109 = cse108*y[4];
# 585:         const double cse110 = k[24]*y[8];
# 586:         const double cse111 = cse110*y[1];
# 587:         const double cse112 = k[25]*y[8];
# 588:         const double cse113 = cse112*y[0];
# 589:         const double cse114 = k[26]*y[8];
# 590:         const double cse115 = cse114*y[0];
# 591:         const double cse116 = k[15]*y[1];
# 592:         const double cse117 = -cse116*y[0];
# 593:         const double cse118 = cse107 + cse109 + cse111 + cse113 + cse115 + cse117;
# 594:         const double cse119 = k[106]*y[27];
# 595:         const double cse120 = cse119*y[14];
# 596:         const double cse121 = k[171]*y[29];
# 597:         const double cse122 = cse121*y[0];
# 598:         const double cse123 = -cse122;
# 599:         const double cse124 = k[120]*y[16];
# 600:         const double cse125 = k[121]*y[16];
# 601:         const double cse126 = cse124*y[9] + cse125*y[9];
# 602:         const double cse127 = cse120 + cse123 + cse126;
# 603:         const double cse128 = k[156]*y[16];
# 604:         const double cse129 = k[157]*y[16];
# 605:         const double cse130 = cse128*y[4] + cse129*y[4];
# 606:         const double cse131 = k[49]*y[14];
# 607:         const double cse132 = k[48]*y[13];
# 608:         const double cse133 = cse131*y[2] - cse132*y[0];
# 609:         const double cse134 = cse130 + cse133;
# 610:         const double cse135 = k[105]*y[27];
# 611:         const double cse136 = cse135*y[6];
# 612:         const double cse137 = k[107]*y[28];
# 613:         const double cse138 = cse137*y[0];
# 614:         const double cse139 = cse136 - cse138;
# 615:         const double cse140 = k[206]*y[6];
# 616:         const double cse141 = cse140*y[2];
# 617:         const double cse142 = k[21]*y[6];
# 618:         const double cse143 = cse142*y[2];
# 619:         const double cse144 = k[20]*y[7];
# 620:         const double cse145 = cse144*y[0];
# 621:         const double cse146 = cse141 + cse143 - cse145;
# 622:         const double cse147 = k[102]*y[26];
# 623:         const double cse148 = cse147*y[10];
# 624:         const double cse149 = k[175]*y[26];
# 625:         const double cse150 = cse149*y[1];
# 626:         const double cse151 = cse148 + cse150;
# 627:         const double cse152 = k[117]*y[26];
# 628:         const double cse153 = cse152*y[14];
# 629:         const double cse154 = k[122]*y[31];
# 630:         const double cse155 = cse154*y[6];
# 631:         const double cse156 = k[158]*y[24];
# 632:         const double cse157 = k[159]*y[24];
# 633:         const double cse158 = cse156*y[2] + cse157*y[2];
# 634:         const double cse159 = cse153 + cse155 + cse158;
# 635:         const double cse160 = k[231]*y[20];
# 636:         const double cse161 = k[267]*y[20];
# 637:         const double cse162 = k[69]*y[20];
# 638:         const double cse163 = cse162*y[6];
# 639:         const double cse164 = k[70]*y[20];
# 640:         const double cse165 = cse164*y[10];
# 641:         const double cse166 = k[200]*y[35];
# 642:         const double cse167 = cse166*y[0];
# 643:         const double cse168 = k[210]*y[10];
# 644:         const double cse169 = cse168*y[0];
# 645:         const double cse170 = k[75]*y[21];
# 646:         const double cse171 = cse170*y[0];
# 647:         const double cse172 = k[143]*y[20];
# 648:         const double cse173 = k[144]*y[20];
# 649:         const double cse174 = cse172*y[2] + cse173*y[2];
# 650:         const double cse175 = cse160 + cse161 + cse163 + cse165 - cse167 - cse169 - cse171 + cse174;
# 651:         const double cse176 = k[244]*y[24];
# 652:         const double cse177 = k[272]*y[24];
# 653:         const double cse178 = k[222]*y[16];
# 654:         const double cse179 = cse178*y[0];
# 655:         const double cse180 = k[285]*y[16];
# 656:         const double cse181 = cse180*y[0];
# 657:         const double cse182 = k[126]*y[24];
# 658:         const double cse183 = cse182*y[9];
# 659:         const double cse184 = k[127]*y[24];
# 660:         const double cse185 = k[128]*y[24];
# 661:         const double cse186 = cse184*y[9] + cse185*y[9];
# 662:         const double cse187 = cse183 + cse186;
# 663:         const double cse188 = cse176 + cse177 - cse179 - cse181 + cse187;
# 664:         const double cse189 = k[151]*y[21];
# 665:         const double cse190 = cse189*y[4];
# 666:         const double cse191 = k[152]*y[21];
# 667:         const double cse192 = cse191*y[4];
# 668:         const double cse193 = k[12]*y[6];
# 669:         const double cse194 = cse193*y[4];
# 670:         const double cse195 = cse190 + cse192 + cse194;
# 671:         const double cse196 = k[273]*y[23];
# 672:         const double cse197 = k[194]*y[18];
# 673:         const double cse198 = cse197*y[1];
# 674:         const double cse199 = k[196]*y[17];
# 675:         const double cse200 = cse199*y[1];
# 676:         const double cse201 = k[71]*y[20];
# 677:         const double cse202 = k[72]*y[20];
# 678:         const double cse203 = cse201*y[14] + cse202*y[14];
# 679:         const double cse204 = k[85]*y[16];
# 680:         const double cse205 = k[86]*y[16];
# 681:         const double cse206 = k[97]*y[19];
# 682:         const double cse207 = cse204*y[10] + cse205*y[10] - cse206*y[0];
# 683:         const double cse208 = cse196 + cse198 + cse200 + cse203 + cse207;
# 684:         const double cse209 = k[241]*y[16];
# 685:         const double cse210 = k[270]*y[16];
# 686:         const double cse211 = k[63]*y[16];
# 687:         const double cse212 = cse211*y[0];
# 688:         const double cse213 = k[84]*y[16];
# 689:         const double cse214 = cse213*y[6];
# 690:         const double cse215 = k[203]*y[36];
# 691:         const double cse216 = cse215*y[0];
# 692:         const double cse217 = k[220]*y[14];
# 693:         const double cse218 = cse217*y[0];
# 694:         const double cse219 = k[284]*y[14];
# 695:         const double cse220 = cse219*y[0];
# 696:         const double cse221 = k[92]*y[24];
# 697:         const double cse222 = cse221*y[0];
# 698:         const double cse223 = k[154]*y[16];
# 699:         const double cse224 = k[155]*y[16];
# 700:         const double cse225 = cse223*y[2] + cse224*y[2];
# 701:         const double cse226 = k[87]*y[16];
# 702:         const double cse227 = cse226*y[14];
# 703:         const double cse228 = k[88]*y[16];
# 704:         const double cse229 = cse228*y[14];
# 705:         const double cse230 = k[89]*y[16];
# 706:         const double cse231 = cse230*y[14];
# 707:         const double cse232 = k[90]*y[16];
# 708:         const double cse233 = cse232*y[14];
# 709:         const double cse234 = k[93]*y[25];
# 710:         const double cse235 = cse234*y[0];
# 711:         const double cse236 = cse227 + cse229 + cse231 + cse233 - cse235;
# 712:         const double cse237 = cse209 + cse210 + cse212 + cse214 - cse216 - cse218 - cse220 - cse222 + cse225 + cse236;
# 713:         const double cse238 = k[172]*y[35];
# 714:         const double cse239 = cse238*y[2];
# 715:         const double cse240 = k[173]*y[36];
# 716:         const double cse241 = cse240*y[2];
# 717:         const double cse242 = k[166]*y[25];
# 718:         const double cse243 = cse242*y[2];
# 719:         const double cse244 = k[257]*y[0];
# 720:         const double cse245 = k[1]*y[2];
# 721:         const double cse246 = cse245*y[1];
# 722:         const double cse247 = k[2]*y[2];
# 723:         const double cse248 = cse247*y[1];
# 724:         const double cse249 = k[60]*y[11];
# 725:         const double cse250 = cse249*y[2];
# 726:         const double cse251 = k[8]*y[3];
# 727:         const double cse252 = cse251*y[2];
# 728:         const double cse253 = k[9]*y[3];
# 729:         const double cse254 = cse253*y[2];
# 730:         const double cse255 = k[0]*y[1];
# 731:         const double cse256 = cse255*y[0];
# 732:         const double cse257 = k[61]*y[15];
# 733:         const double cse258 = cse257*y[0];
# 734:         const double cse259 = k[7]*y[4];
# 735:         const double cse260 = cse259*y[0];
# 736:         const double cse261 = k[56]*y[12];
# 737:         const double cse262 = k[57]*y[12];
# 738:         const double cse263 = cse261*y[2] + cse262*y[2];
# 739:         const double cse264 = k[147]*y[21];
# 740:         const double cse265 = k[148]*y[21];
# 741:         const double cse266 = cse264*y[2] + cse265*y[2];
# 742:         const double cse267 = k[51]*y[10];
# 743:         const double cse268 = cse267*y[2];
# 744:         const double cse269 = k[52]*y[9];
# 745:         const double cse270 = cse269*y[0];
# 746:         const double cse271 = cse268 - cse270;
# 747:         const double cse272 = cse239 + cse241 + cse243 - cse244 + cse246 + cse248 + cse250 + cse252 + cse254 - cse256 - cse258 - cse260 + cse263 + cse266 + cse271;
# 748:         const double cse273 = k[67]*y[10];
# 749:         const double cse274 = cse273*y[6];
# 750:         const double cse275 = k[68]*y[20];
# 751:         const double cse276 = cse275*y[0];
# 752:         const double cse277 = cse274 - cse276;
# 753:         const double cse278 = k[82]*y[14];
# 754:         const double cse279 = cse278*y[6];
# 755:         const double cse280 = k[83]*y[16];
# 756:         const double cse281 = cse280*y[0];
# 757:         const double cse282 = cse279 - cse281;
# 758:         const double cse283 = -cse200;
# 759:         const double cse284 = k[235]*y[21];
# 760:         const double cse285 = k[271]*y[21];
# 761:         const double cse286 = k[179]*y[28];
# 762:         const double cse287 = cse286*y[1];
# 763:         const double cse288 = -cse287;
# 764:         const double cse289 = -cse66;
# 765:         const double cse290 = k[245]*y[24];
# 766:         const double cse291 = k[185]*y[32];
# 767:         const double cse292 = cse291*y[1];
# 768:         const double cse293 = -cse292;
# 769:         const double cse294 = -cse38;
# 770:         const double cse295 = -cse70;
# 771:         const double cse296 = -cse91;
# 772:         const double cse297 = -cse105;
# 773:         const double cse298 = k[258]*y[3];
# 774:         const double cse299 = k[3]*y[3];
# 775:         const double cse300 = cse299*y[1];
# 776:         const double cse301 = k[4]*y[4];
# 777:         const double cse302 = cse301*y[1];
# 778:         const double cse303 = k[5]*y[4];
# 779:         const double cse304 = cse303*y[1];
# 780:         const double cse305 = k[62]*y[15];
# 781:         const double cse306 = cse305*y[1];
# 782:         const double cse307 = k[230]*y[35];
# 783:         const double cse308 = k[201]*y[35];
# 784:         const double cse309 = cse308*y[6];
# 785:         const double cse310 = k[202]*y[35];
# 786:         const double cse311 = cse310*y[14];
# 787:         const double cse312 = k[209]*y[10];
# 788:         const double cse313 = cse312*y[1];
# 789:         const double cse314 = cse167 + cse307 + cse309 + cse311 - cse313;
# 790:         const double cse315 = k[240]*y[36];
# 791:         const double cse316 = k[204]*y[36];
# 792:         const double cse317 = cse316*y[6];
# 793:         const double cse318 = k[205]*y[36];
# 794:         const double cse319 = cse318*y[10];
# 795:         const double cse320 = k[219]*y[14];
# 796:         const double cse321 = cse320*y[1];
# 797:         const double cse322 = cse216 + cse315 + cse317 + cse319 - cse321;
# 798:         const double cse323 = k[46]*y[12];
# 799:         const double cse324 = k[41]*y[11];
# 800:         const double cse325 = k[42]*y[11];
# 801:         const double cse326 = cse323*y[1] - cse324*y[1] - cse325*y[1];
# 802:         const double cse327 = k[254]*y[25];
# 803:         const double cse328 = k[269]*y[25];
# 804:         const double cse329 = k[192]*y[34];
# 805:         const double cse330 = cse327 + cse328 - cse329*y[1];
# 806:         const double cse331 = k[242]*y[16];
# 807:         const double cse332 = -cse36;
# 808:         const double cse333 = cse331 + cse332;
# 809:         const double cse334 = k[197]*y[10];
# 810:         const double cse335 = cse334*y[8];
# 811:         const double cse336 = k[198]*y[14];
# 812:         const double cse337 = cse336*y[8];
# 813:         const double cse338 = k[199]*y[16];
# 814:         const double cse339 = cse338*y[8];
# 815:         const double cse340 = cse335 + cse337 + cse339;
# 816:         const double cse341 = k[261]*y[19];
# 817:         const double cse342 = k[193]*y[29];
# 818:         const double cse343 = -cse342*y[1];
# 819:         const double cse344 = cse341 + cse343;
# 820:         const double cse345 = k[274]*y[23];
# 821:         const double cse346 = k[195]*y[18];
# 822:         const double cse347 = -cse346*y[1];
# 823:         const double cse348 = -cse198 + cse345 + cse347;
# 824:         const double cse349 = k[28]*y[8];
# 825:         const double cse350 = cse349*y[2];
# 826:         const double cse351 = k[265]*y[6];
# 827:         const double cse352 = cse350 + cse351 - cse82 - cse84;
# 828:         const double cse353 = k[232]*y[20];
# 829:         const double cse354 = -cse32;
# 830:         const double cse355 = cse353 + cse354;
# 831:         const double cse356 = -cse34;
# 832:         const double cse357 = k[73]*y[20];
# 833:         const double cse358 = cse357*y[14];
# 834:         const double cse359 = k[182]*y[30];
# 835:         const double cse360 = cse359*y[1];
# 836:         const double cse361 = cse356 + cse358 - cse360 - cse68;
# 837:         const double cse362 = k[6]*y[4];
# 838:         const double cse363 = cse362*y[1];
# 839:         const double cse364 = k[14]*y[5];
# 840:         const double cse365 = cse364*y[1];
# 841:         const double cse366 = cse363 - cse365;
# 842:         const double cse367 = k[191]*y[33];
# 843:         const double cse368 = cse367*y[1];
# 844:         const double cse369 = -cse368 - cse72;
# 845:         const double cse370 = k[229]*y[10];
# 846:         const double cse371 = k[266]*y[10];
# 847:         const double cse372 = k[45]*y[10];
# 848:         const double cse373 = cse372*y[1];
# 849:         const double cse374 = k[38]*y[9];
# 850:         const double cse375 = cse374*y[1];
# 851:         const double cse376 = k[39]*y[9];
# 852:         const double cse377 = cse376*y[1];
# 853:         const double cse378 = k[40]*y[9];
# 854:         const double cse379 = cse378*y[1];
# 855:         const double cse380 = cse370 + cse371 + cse373 - cse375 - cse377 - cse379;
# 856:         const double cse381 = k[47]*y[14];
# 857:         const double cse382 = k[43]*y[13];
# 858:         const double cse383 = k[44]*y[13];
# 859:         const double cse384 = cse381*y[1] - cse382*y[1] - cse383*y[1] + k[259]*y[14];
# 860:         const double cse385 = -cse103 + cse384;
# 861:         const double cse386 = -k[247]*y[32];
# 862:         const double cse387 = k[227]*y[26];
# 863:         const double cse388 = k[208]*y[6];
# 864:         const double cse389 = cse388*y[2];
# 865:         const double cse390 = -k[243]*y[31];
# 866:         const double cse391 = cse225 + cse390;
# 867:         const double cse392 = -k[264]*y[6];
# 868:         const double cse393 = cse350 + cse392 + cse80;
# 869:         const double cse394 = cse146 - cse18 + cse48 + cse50;
# 870:         const double cse395 = -k[233]*y[27];
# 871:         const double cse396 = cse174 + cse395;
# 872:         const double cse397 = k[250]*y[33];
# 873:         const double cse398 = cse158 - cse397;
# 874:         const double cse399 = k[160]*y[24];
# 875:         const double cse400 = cse399*y[4];
# 876:         const double cse401 = k[161]*y[24];
# 877:         const double cse402 = cse401*y[4];
# 878:         const double cse403 = -cse400 - cse402;
# 879:         const double cse404 = k[145]*y[21];
# 880:         const double cse405 = k[146]*y[21];
# 881:         const double cse406 = cse404*y[2] + cse405*y[2];
# 882:         const double cse407 = -cse17 - cse194 + cse406;
# 883:         const double cse408 = k[58]*y[12];
# 884:         const double cse409 = cse408*y[4];
# 885:         const double cse410 = k[167]*y[25];
# ...
# 3033:         J(6, 1) = cse102 + cse149 + cse286 + cse291 + cse359 + cse367 - cse75;
# 3034:         J(6, 2) = -cse388 + cse404 + cse405 - cse622 - cse73;
# 3035:         J(6, 3) = cse19*k[33] - cse61;
# 3036:         J(6, 4) = -cse193 - cse416 + cse428 + cse430 - cse63;
# 3037:         J(6, 6) = cse19*k[36] + cse19*k[37] - cse449 - cse635 - cse636 - cse637 - cse638 - cse639 - 2*cse640 - cse646 - cse781 - cse851 - cse871 - cse872 - cse873 - cse874 - cse875 - k[226] - k[263] - k[264];
# 3038:         J(6, 7) = cse1 + cse647 - cse650;
# 3039:         J(6, 8) = cse876;
# 3040:         J(6, 9) = -cse878;
# 3041:         J(6, 10) = cse442 + cse478 - cse666 - cse879;
# 3042:         J(6, 13) = -cse673;
# 3043:         J(6, 14) = cse445 + cse463 - cse676 + cse880;
# 3044:         J(6, 16) = -cse684 + cse882;
# 3045:         J(6, 19) = cse885;
# 3046:         J(6, 20) = cse702 - cse705;
# 3047:         J(6, 21) = cse710 + cse835 + cse858 + cse886;
# 3048:         J(6, 24) = cse888;
# 3049:         J(6, 25) = -cse889;
# 3050:         J(6, 26) = cse725 + cse727 + cse890 + cse891 + cse897;
# 3051:         J(6, 27) = cse729 - cse730;
# 3052:         J(6, 28) = -cse733 + cse736 + cse808;
# 3053:         J(6, 30) = cse740 + cse812 + cse901;
# 3054:         J(6, 31) = -cse742;
# 3055:         J(6, 32) = -cse747 + cse815 + k[248];
# 3056:         J(6, 33) = cse817 + cse903;
# 3057:         J(6, 35) = -cse820;
# 3058:         J(6, 36) = -cse823;
# 3059:         J(7, 0) = -cse144 + cse604;
# 3060:         J(7, 1) = -cse759;
# 3061:         J(7, 2) = cse349 + cse829;
# 3062:         J(7, 4) = cse416;
# 3063:         J(7, 6) = -cse39 + cse645 + cse850 + k[265];
# 3064:         J(7, 7) = -cse651 - cse782 - cse833;
# 3065:         J(7, 8) = -cse652 + cse783;
# 3066:         J(7, 10) = -cse665;
# 3067:         J(7, 14) = -cse680;
# 3068:         J(7, 26) = cse904;
# 3069:         J(7, 32) = k[246];
# 3070:         J(7, 33) = k[251];
# 3071:         J(8, 0) = -cse757;
# 3072:         J(8, 1) = cse760;
# 3073:         J(8, 2) = -cse826;
# 3074:         J(8, 4) = -cse108;
# 3075:         J(8, 6) = k[264];
# 3076:         J(8, 7) = -cse1;
# 3077:         J(8, 8) = -cse658 - cse785 - cse834 - cse876;
# 3078:         J(8, 10) = -cse787;
# 3079:         J(8, 14) = -cse796;
# 3080:         J(8, 16) = -cse799;
# 3081:         J(9, 0) = -cse269 - cse905;
# 3082:         J(9, 1) = -cse772;
# 3083:         J(9, 2) = cse267;
# 3084:         J(9, 4) = cse418 + cse842 + cse848;
# 3085:         J(9, 6) = -cse871;
# 3086:         J(9, 9) = -cse660 - cse878 - cse906 - cse907 - cse908 - cse910;
# 3087:         J(9, 10) = cse501 + cse668 + cse789 + cse852;
# 3088:         J(9, 12) = -cse911;
# 3089:         J(9, 14) = -cse912;
# 3090:         J(9, 16) = -cse690;
# 3091:         J(9, 19) = cse855;
# 3092:         J(9, 21) = cse858;
# 3093:         J(9, 22) = cse860;
# 3094:         J(9, 24) = -cse914;
# 3095:         J(9, 25) = -cse917;
# 3096:         J(9, 27) = cse729;
# 3097:         J(9, 34) = cse918;
# 3098:         J(10, 0) = -cse168 + cse605;
# 3099:         J(10, 1) = -cse312 + cse346 + cse773;
# 3100:         J(10, 2) = cse238 - cse267;
# 3101:         J(10, 4) = cse420 - cse847 - cse919;
# 3102:         J(10, 6) = -cse872;
# 3103:         J(10, 7) = -cse10;
# 3104:         J(10, 8) = -cse334;
# 3105:         J(10, 9) = cse504 + cse908;
# 3106:         J(10, 10) = -cse442 - cse670 - cse788 - cse790 - cse852 - cse879 - cse920*k[212] - cse920*k[276] - cse920*k[277] - cse921 - cse922 - cse923 - cse924 - cse925 - cse928;
# 3107:         J(10, 12) = cse911;
# 3108:         J(10, 13) = -cse929 - cse930;
# 3109:         J(10, 14) = cse534 + cse536 + cse555 - cse931;
# 3110:         J(10, 16) = -cse691;
# 3111:         J(10, 18) = cse801 - cse932;
# 3112:         J(10, 19) = cse856 + cse934;
# 3113:         J(10, 20) = -cse706 + cse935 + cse936;
# 3114:         J(10, 22) = cse939 + 2*k[239] + 2*k[262];
# 3115:         J(10, 24) = cse913;
# 3116:         J(10, 25) = -cse940;
# 3117:         J(10, 26) = -cse941;
# 3118:         J(10, 27) = cse942;
# 3119:         J(10, 28) = cse809;
# 3120:         J(10, 29) = cse811;
# 3121:         J(10, 33) = -cse902;
# 3122:         J(10, 34) = -cse944;
# 3123:         J(10, 35) = cse945;
# 3124:         J(10, 36) = -cse824;
# 3125:         J(11, 0) = cse257;
# 3126:         J(11, 1) = -cse764 - cse946;
# 3127:         J(11, 2) = -cse249 + cse624;
# 3128:         J(11, 4) = cse408;
# 3129:         J(11, 9) = cse499;
# 3130:         J(11, 11) = -cse671 - cse791;
# 3131:         J(11, 12) = cse947;
# 3132:         J(11, 15) = cse948;
# 3133:         J(12, 1) = cse764;
# 3134:         J(12, 2) = -cse624;
# 3135:         J(12, 4) = -cse408;
# 3136:         J(12, 9) = -cse499;
# 3137:         J(12, 11) = cse791;
# 3138:         J(12, 12) = -cse947;
# 3139:         J(13, 0) = -cse132;
# 3140:         J(13, 1) = -cse774;
# 3141:         J(13, 2) = cse131;
# 3142:         J(13, 4) = cse414 + cse420 + cse844;
# 3143:         J(13, 6) = -cse94;
# 3144:         J(13, 9) = cse516;
# 3145:         J(13, 10) = -cse921;
# 3146:         J(13, 13) = -cse673 - cse949 - cse950;
# 3147:         J(13, 14) = cse951;
# 3148:         J(13, 16) = cse689;
# 3149:         J(13, 19) = cse856;
# 3150:         J(13, 22) = -cse937;
# 3151:         J(13, 25) = cse866 + cse916;
# 3152:         J(13, 32) = k[248];
# 3153:         J(14, 0) = cse211 - cse217 - cse219 + cse607;
# 3154:         J(14, 1) = cse102 - cse320 + 2*cse329 + cse342 + cse767 + cse775;
# 3155:         J(14, 2) = -cse131 + cse240;
# 3156:         J(14, 4) = cse414 + cse418 - cse422;
# 3157:         J(14, 6) = -cse278;
# 3158:         J(14, 7) = -cse96;
# 3159:         J(14, 8) = -cse336;
# 3160:         J(14, 9) = cse507 - cse909;
# 3161:         J(14, 10) = cse538 + cse549 + cse551 - cse927;
# 3162:         J(14, 13) = cse949;
# 3163:         J(14, 14) = -cse682 - cse794 - cse797 - cse880 - cse951 - cse952*k[221] - cse952*k[286] - cse953 - cse954 - cse956 - cse957 - cse958 - cse959 - cse961;
# 3164:         J(14, 16) = cse687 - cse692 - cse693 - cse694 - cse695 + cse697 + cse963;
# 3165:         J(14, 19) = cse855 + cse933;
# 3166:         J(14, 20) = -cse803 - cse964;
# 3167:         J(14, 21) = -cse965 - cse967;
# 3168:         J(14, 22) = -cse938;
# 3169:         J(14, 25) = cse722 + cse866 + cse915 + cse940 + 2*k[255] + 2*k[268];
# 3170:         J(14, 26) = -cse968;
# 3171:         J(14, 27) = -cse731;
# 3172:         J(14, 28) = -cse734;
# 3173:         J(14, 29) = cse811;
# 3174:         J(14, 30) = -cse900;
# 3175:         J(14, 31) = cse743 + k[243];
# 3176:         J(14, 32) = cse969;
# 3177:         J(14, 33) = cse751;
# 3178:         J(14, 34) = 2*cse819 + cse943;
# 3179:         J(14, 35) = -cse821;
# 3180:         J(14, 36) = cse970;
# 3181:         J(15, 0) = -cse257;
# 3182:         J(15, 1) = cse946;
# 3183:         J(15, 2) = cse249;
# 3184:         J(15, 11) = cse671;
# 3185:         J(15, 15) = -cse948;
# 3186:         J(16, 0) = -cse178 - cse180 + cse206 + cse215 + cse234 - cse280 + cse611;
# 3187:         J(16, 1) = cse346 + cse37 + cse769;
# 3188:         J(16, 2) = -cse625;
# 3189:         J(16, 4) = cse399 + cse401 - cse634;
# 3190:         J(16, 6) = -cse213 + cse278 + 2*cse449;
# 3191:         J(16, 8) = cse336 - cse338;
# 3192:         J(16, 9) = -cse662;
# 3193:         J(16, 10) = -cse669;
# 3194:         J(16, 14) = -cse226 - cse228 - cse230 - cse232 + cse555 + cse569 + cse796 + cse959;
# 3195:         J(16, 16) = -cse698 - cse800 - cse882 - 4*cse962 - cse971;
# 3196:         J(16, 18) = cse801;
# 3197:         J(16, 19) = cse701;
# 3198:         J(16, 20) = cse935;
# 3199:         J(16, 21) = cse965;
# 3200:         J(16, 24) = cse714 + cse972;
# 3201:         J(16, 25) = 2*cse889 + cse973;
# 3202:         J(16, 26) = -cse892;
# 3203:         J(16, 28) = cse974;
# 3204:         J(16, 32) = cse975;
# 3205:         J(16, 33) = cse976;
# 3206:         J(16, 36) = cse756;
# 3207:         J(17, 1) = -cse199;
# 3208:         J(17, 6) = -cse581;
# 3209:         J(17, 9) = cse182;
# 3210:         J(17, 14) = cse451;
# 3211:         J(17, 17) = -cse699 - cse977;
# 3212:         J(17, 19) = cse883 - cse978 - cse979;
# 3213:         J(17, 24) = cse717;
# 3214:         J(17, 26) = cse894;
# 3215:         J(17, 30) = cse898;
# 3216:         J(18, 1) = -cse761;
# 3217:         J(18, 6) = cse581;
# 3218:         J(18, 9) = cse663;
# 3219:         J(18, 10) = cse442 - cse546;
# 3220:         J(18, 14) = cse469 + cse954;
# 3221:         J(18, 17) = cse977;
# 3222:         J(18, 18) = -cse802 - cse981;
# 3223:         J(18, 19) = cse884 + cse978 + cse979;
# 3224:         J(18, 20) = cse803;
# 3225:         J(18, 23) = k[274];
# 3226:         J(18, 24) = cse718 - cse982 - cse983;
# 3227:         J(18, 25) = cse576;
# 3228:         J(18, 26) = cse895;
# 3229:         J(18, 28) = cse984;
# 3230:         J(18, 30) = cse899;
# 3231:         J(18, 33) = cse902;
# 3232:         J(19, 0) = cse121 - cse206;
# 3233:         J(19, 1) = cse615;
# 3234:         J(19, 4) = -cse840;
# 3235:         J(19, 9) = cse516;
# 3236:         J(19, 10) = cse318 + cse546 + cse669 + cse928;
# 3237:         J(19, 14) = cse310 + cse679 + cse955 + cse961;
# 3238:         J(19, 16) = cse691;
# 3239:         J(19, 17) = cse699;
# 3240:         J(19, 18) = cse700 + cse981;
# 3241:         J(19, 19) = -cse857 - cse885 - cse934 - k[261];
# 3242:         J(19, 20) = cse703;
# 3243:         J(19, 21) = cse966;
# 3244:         J(19, 22) = cse938;
# 3245:         J(19, 23) = k[273];
# 3246:         J(19, 24) = cse985;
# 3247:         J(19, 25) = cse916 + cse940;
# 3248:         J(19, 26) = -cse896;
# 3249:         J(19, 29) = cse738;
# 3250:         J(19, 35) = cse821;
# 3251:         J(19, 36) = cse824;
# 3252:         J(20, 0) = -cse275 + cse606;
# 3253:         J(20, 1) = cse766;
# 3254:         J(20, 2) = -cse626;
# 3255:         J(20, 6) = -cse162 + cse273;
# 3256:         J(20, 8) = cse334;
# 3257:         J(20, 10) = -cse164 + cse925;
# 3258:         J(20, 14) = -cse357 + cse569 - cse957;
# 3259:         J(20, 20) = -cse708 - cse804 - cse936 - cse964;
# 3260:         J(20, 21) = cse986;
# 3261:         J(20, 28) = cse735;
# 3262:         J(20, 30) = cse813;
# 3263:         J(20, 35) = cse754;
# 3264:         J(21, 0) = -cse170;
# 3265:         J(21, 1) = cse90;
# 3266:         J(21, 2) = -cse828;
# 3267:         J(21, 4) = -cse843;
# 3268:         J(21, 6) = cse489 + cse875;
# 3269:         J(21, 10) = cse879;
# 3270:         J(21, 14) = -cse956;
# 3271:         J(21, 20) = cse705;
# 3272:         J(21, 21) = -cse805 - cse836 - cse859 - cse967 - cse986;
# 3273:         J(21, 30) = cse739;
# 3274:         J(21, 35) = cse820;
# 3275:         J(22, 4) = cse919;
# 3276:         J(22, 10) = cse164 + cse987*k[212] + cse987*k[276] + cse987*k[277];
# 3277:         J(22, 13) = cse929;
# 3278:         J(22, 14) = -cse960;
# 3279:         J(22, 20) = cse706;
# 3280:         J(22, 22) = -cse939 - k[239] - k[262];
# 3281:         J(23, 14) = cse7;
# 3282:         J(23, 21) = cse709;
# 3283:         J(23, 23) = -k[273] - k[274];
# 3284:         J(24, 0) = -cse221 + cse603;
# 3285:         J(24, 1) = cse104;
# 3286:         J(24, 2) = -cse627;
# 3287:         J(24, 4) = -cse830 - cse846;
# 3288:         J(24, 6) = cse873;
# 3289:         J(24, 8) = cse338;
# 3290:         J(24, 9) = -cse907;
# 3291:         J(24, 16) = cse799 + cse963 + cse971;
# 3292:         J(24, 18) = -cse980;
# 3293:         J(24, 24) = -cse863 - cse888 - cse914 - cse972 - cse985 - cse988;
# 3294:         J(24, 26) = -cse893;
# 3295:         J(24, 33) = cse989;
# 3296:         J(24, 36) = cse823;
# 3297:         J(25, 0) = -cse234;
# 3298:         J(25, 2) = -cse242;
# 3299:         J(25, 4) = -cse841;
# 3300:         J(25, 6) = -cse449;
# 3301:         J(25, 9) = -cse906;
# 3302:         J(25, 10) = cse501 - cse926;
# 3303:         J(25, 14) = cse681 + cse990*k[221] + cse990*k[286];
# 3304:         J(25, 16) = cse696;
# 3305:         J(25, 25) = -cse867 - cse889 - cse917 - cse940 - cse973 - cse991 - k[255] - k[268];
# 3306:         J(25, 28) = -cse974;
# 3307:         J(25, 34) = cse918;
# 3308:         J(26, 0) = -cse53;
# 3309:         J(26, 1) = -cse762;
# 3310:         J(26, 2) = cse388;
# 3311:         J(26, 6) = cse874;
# 3312:         J(26, 7) = cse650;
# 3313:         J(26, 10) = -cse922;
# 3314:         J(26, 14) = -cse953;
# 3315:         J(26, 16) = -cse881;
# 3316:         J(26, 19) = -cse885;
# 3317:         J(26, 24) = -cse887;
# 3318:         J(26, 26) = -cse807 - cse897 - cse904 - cse941 - cse968;
# 3319:         J(27, 0) = cse137 + cse905;
# 3320:         J(27, 1) = -cse31;
# 3321:         J(27, 2) = cse626 + cse827;
# 3322:         J(27, 4) = cse632;
# 3323:         J(27, 6) = cse12 - cse135;
# 3324:         J(27, 7) = cse10;
# 3325:         J(27, 9) = cse659 + cse660;
# 3326:         J(27, 10) = cse478 + cse924;
# 3327:         J(27, 14) = -cse119;
# 3328:         J(27, 18) = cse932;
# 3329:         J(27, 20) = cse707 + k[232];
# 3330:         J(27, 21) = cse713 + cse835;
# 3331:         J(27, 26) = cse890;
# 3332:         J(27, 27) = -cse729 - cse732 - cse942;
# 3333:         J(27, 28) = cse992;
# 3334:         J(27, 30) = k[238];
# 3335:         J(28, 0) = -cse137 - cse993;
# 3336:         J(28, 1) = -cse33 - cse771;
# 3337:         J(28, 2) = cse621;
# 3338:         J(28, 6) = cse135 - cse27 + cse447;
# 3339:         J(28, 9) = cse877;
# 3340:         J(28, 10) = cse147;
# 3341:         J(28, 14) = -cse3;
# 3342:         J(28, 21) = cse712 + cse805;
# 3343:         J(28, 25) = -cse576;
# 3344:         J(28, 26) = cse723;
# 3345:         J(28, 27) = cse730;
# 3346:         J(28, 28) = -cse733 - cse810 - cse984 - cse992;
# 3347:         J(28, 30) = cse994;
# 3348:         J(29, 0) = -cse121;
# 3349:         J(29, 1) = -cse342;
# 3350:         J(29, 9) = cse507 + cse910;
# 3351:         J(29, 10) = cse538 + cse921;
# 3352:         J(29, 13) = cse950;
# 3353:         J(29, 14) = cse958;
# 3354:         J(29, 16) = cse690;
# 3355:         J(29, 19) = k[261];
# 3356:         J(29, 22) = cse937;
# 3357:         J(29, 25) = cse915;
# 3358:         J(29, 27) = cse731;
# 3359:         J(29, 29) = -cse738 - cse811;
# 3360:         J(29, 34) = cse943;
# 3361:         J(30, 0) = cse993;
# 3362:         J(30, 1) = -cse765 - cse90;
# 3363:         J(30, 6) = cse27;
# 3364:         J(30, 14) = -cse880;
# 3365:         J(30, 28) = cse733;
# 3366:         J(30, 30) = -cse814 - cse901 - cse994;
# 3367:         J(31, 1) = -cse35;
# 3368:         J(31, 2) = cse625;
# 3369:         J(31, 4) = cse633;
# 3370:         J(31, 6) = -cse154 + cse94;
# 3371:         J(31, 7) = cse96;
# 3372:         J(31, 13) = cse673;
# 3373:         J(31, 14) = cse463 + cse680;
# 3374:         J(31, 16) = cse688 + k[242];
# 3375:         J(31, 24) = cse715;
# 3376:         J(31, 26) = cse891;
# 3377:         J(31, 31) = -cse744 - k[243];
# 3378:         J(31, 32) = k[249];
# 3379:         J(31, 33) = k[253];
# 3380:         J(32, 1) = -cse768;
# 3381:         J(32, 2) = cse627;
# 3382:         J(32, 4) = cse845;
# 3383:         J(32, 6) = cse154 - cse29;
# 3384:         J(32, 9) = cse504;
# 3385:         J(32, 14) = cse152;
# 3386:         J(32, 16) = cse881;
# 3387:         J(32, 24) = cse862 + cse913 + cse988;
# 3388:         J(32, 26) = cse724 + cse892;
# 3389:         J(32, 31) = cse742;
# 3390:         J(32, 32) = -cse748 - cse969 - cse975 - k[248];
# 3391:         J(32, 33) = k[252];
# 3392:         J(33, 1) = -cse770;
# 3393:         J(33, 6) = cse29;
# 3394:         J(33, 10) = -cse442;
# 3395:         J(33, 18) = cse980;
# 3396:         J(33, 24) = cse887 + cse985;
# 3397:         J(33, 26) = cse893;
# 3398:         J(33, 32) = cse747;
# 3399:         J(33, 33) = -cse903 - cse976 - cse989 - k[252];
# 3400:         J(34, 1) = -cse329;
# 3401:         J(34, 2) = cse242;
# 3402:         J(34, 4) = cse410;
# 3403:         J(34, 10) = -cse923;
# 3404:         J(34, 25) = cse865 + cse991;
# 3405:         J(34, 34) = -cse819 - cse944;
# 3406:         J(35, 0) = -cse166;
# 3407:         J(35, 1) = cse312;
# 3408:         J(35, 2) = -cse238;
# 3409:         J(35, 6) = -cse308;
# 3410:         J(35, 10) = cse788;
# 3411:         J(35, 14) = -cse310;
# 3412:         J(35, 35) = -cse822 - cse945;
# 3413:         J(36, 0) = -cse215;
# 3414:         J(36, 1) = cse320;
# 3415:         J(36, 2) = -cse240;
# 3416:         J(36, 6) = -cse316;
# 3417:         J(36, 10) = -cse318;
# 3418:         J(36, 14) = cse794;
# 3419:         J(36, 36) = -cse825 - cse970;
# 3420:
# 3421:         // PREPROCESS_END
# 3422:     }
# 3423: };

# %%
# Show main function structure from chemistry_ode.cpp
with open(builds_dir + "/chemistry_ode.cpp", 'r') as f:
    lines = f.readlines()

# Find main function
main_start = None
for i, line in enumerate(lines):
    if "int main(" in line:
        main_start = i
        break

if main_start:
    print("Main function structure:")
    print("=" * 50)
    for i in range(main_start, len(lines)):
        line = lines[i].rstrip()
        print(f"{i+1:2d}: {line}")
# Out:
# Main function structure:
# ==================================================
# 41: int main(int argc, char* argv[]) {
# 42:     Kokkos::initialize(argc, argv);
# 43:
# 44:     {
# 45:         using execution_space = Kokkos::DefaultExecutionSpace;
# 46:         using scalar_type = double;
# 47:         using vec_type = Kokkos::View<scalar_type*, execution_space>;
# 48:         using mat_type = Kokkos::View<scalar_type**, execution_space>;
# 49:
# 50:         ChemistryODE mySys{};
# 51:
# 52:         // Time integration parameters
# 53:         const scalar_type t_start = 0.0;
# 54:         scalar_type t_end = 3.15576e9; // 100 years in seconds default
# 55:
# 56:         // Parse command line arguments
# 57:         if (argc > 1) {
# 58:             t_end = std::stod(argv[1]);
# 59:         }
# 60:
# 61:         std::cout << "Solving Chemistry ODE System\n";
# 62:         std::cout << "Number of species: " << mySys.neqs << "\n";
# 63:         std::cout << "Number of reactions: " <<
# 64: // PREPROCESS_NUM_REACTIONS
# 65:
# 66: 287
# 67:
# 68: // PREPROCESS_END
# 69:          << "\n";
# 70:         std::cout << "Time interval: [" << t_start << ", " << t_end << "] seconds\n";
# 71:
# 72:         // Allocate arrays
# 73:         vec_type y0("initial conditions", mySys.neqs);
# 74:         vec_type y_new("solution", mySys.neqs);
# 75:
# 76:         // Set initial conditions (can be customized)
# 77:         auto y0_h = Kokkos::create_mirror_view(y0);
# 78:
# 79:         // Default: all species start at 1e-10 except first species
# 80:         for (int i = 0; i < mySys.neqs; ++i) {
# 81:             y0_h(i) = 1.0e-10;
# 82:         }
# 83:         // Set first species to higher concentration
# 84:         if (mySys.neqs > 0) {
# 85:             y0_h(0) = 1.0e-6;
# 86:         }
# 87:
# 88:         // Read initial conditions from file if provided
# 89:         if (argc > 2) {
# 90:             std::ifstream ic_file(argv[2]);
# 91:             if (ic_file.is_open()) {
# 92:                 for (int i = 0; i < mySys.neqs && ic_file >> y0_h(i); ++i) {}
# 93:                 ic_file.close();
# 94:                 std::cout << "Initial conditions loaded from " << argv[2] << "\n";
# 95:             }
# 96:         }
# 97:
# 98:         Kokkos::deep_copy(y0, y0_h);
# 99:
# 100:         // Print initial conditions
# 101:         std::cout << "Initial conditions:\n";
# 102:         for (int i = 0; i < mySys.neqs && i < 10; ++i) {
# 103:             std::cout << "  y[" << i << "] = " << y0_h(i) << "\n";
# 104:         }
# 105:         if (mySys.neqs > 10) {
# 106:             std::cout << "  ... (showing first 10 species)\n";
# 107:         }
# 108:
# 109:         // Allocate temporary storage for BDF solver
# 110:         mat_type temp("buffer1", mySys.neqs, 23 + 2 * mySys.neqs + 4);
# 111:         mat_type temp2("buffer2", 6, 7);
# 112:
# 113:         // Initial time step (will be adapted by solver)
# 114:         scalar_type dt = 1.0e-10;
# 115:         scalar_type max_step = (t_end - t_start) / 100.0;
# 116:
# 117:         // Create solver wrapper
# 118:         BDF_Solve_wrapper<ChemistryODE, vec_type, mat_type, scalar_type> bdf_wrapper(
# 119:             mySys, t_start, t_end, dt, max_step, y0, y_new, temp, temp2);
# 120:
# 121:         // Run solver
# 122:         Kokkos::RangePolicy<execution_space> policy(0, 1);
# 123:         Kokkos::parallel_for(policy, bdf_wrapper);
# 124:         Kokkos::fence();
# 125:
# 126:         // Copy solution back to host
# 127:         auto y_new_h = Kokkos::create_mirror_view(y_new);
# 128:         Kokkos::deep_copy(y_new_h, y_new);
# 129:
# 130:         // Print final solution
# 131:         std::cout << "\nFinal solution at t = " << t_end << " seconds:\n";
# 132:         for (int i = 0; i < mySys.neqs && i < 10; ++i) {
# 133:             std::cout << "  y[" << i << "] = " << y_new_h(i) << "\n";
# 134:         }
# 135:         if (mySys.neqs > 10) {
# 136:             std::cout << "  ... (showing first 10 species)\n";
# 137:         }
# 138:
# 139:         // Write solution to file if output path provided
# 140:         if (argc > 3) {
# 141:             std::ofstream out_file(argv[3]);
# 142:             if (out_file.is_open()) {
# 143:                 for (int i = 0; i < mySys.neqs; ++i) {
# 144:                     out_file << y_new_h(i) << "\n";
# 145:                 }
# 146:                 out_file.close();
# 147:                 std::cout << "\nSolution written to " << argv[3] << "\n";
# 148:             }
# 149:         }
# 150:
# 151:         // Check conservation (sum of all species)
# 152:         double sum_initial = 0.0, sum_final = 0.0;
# 153:         for (int i = 0; i < mySys.neqs; ++i) {
# 154:             sum_initial += y0_h(i);
# 155:             sum_final += y_new_h(i);
# 156:         }
# 157:         std::cout << "\nConservation check:\n";
# 158:         std::cout << "  Initial sum: " << sum_initial << "\n";
# 159:         std::cout << "  Final sum:   " << sum_final << "\n";
# 160:         std::cout << "  Relative change: " << (sum_final - sum_initial) / sum_initial << "\n";
# 161:
# 162:         std::cout << "\nKokkos execution space: "
# 163:                   << typeid(Kokkos::DefaultExecutionSpace).name() << std::endl;
# 164:     }
# 165:
# 166:     Kokkos::finalize();
# 167:
# 168:     return 0;
# 169: }

# %% [markdown]
# ## Step 6: Building and Running Instructions
#
# Here's how to build and run the generated C++ code:

# %% [markdown]
# * **Configure the build with CMake:**

# %%
!   cmake -S . -B build
# Out:
# -- Setting default Kokkos CXX standard to 17
# -- Kokkos version: 4.7.0
# -- The project name is: Kokkos
# -- Using internal gtest for testing
# -- Using -std=c++17 for C++17 standard as feature
# -- Built-in Execution Spaces:
# --     Device Parallel: NoTypeDefined
# --     Host Parallel: NoTypeDefined
# --       Host Serial: SERIAL
# --
# -- Architectures:
# -- Using internal desul_atomics copy
# -- Performing Test KOKKOS_LINK_OPTIONS_CHECK
# -- Performing Test KOKKOS_LINK_OPTIONS_CHECK - Success
# -- Experimental mdspan support is enabled
# -- Using internal mdspan directory /Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkos-src/tpls/mdspan/include
# -- Kokkos Backends: SERIAL
# -- The project name is: KokkosKernels
#
# ================================
# Kokkos Kernels version: 4.7.0
# ================================
# Kokkos Kernels ETI Types
#    Devices:  <Serial,HostSpace>
#    Scalars:  double
#    Ordinals: int
#    Offsets:  int
#    Layouts:  LayoutLeft
#
# Kokkos Kernels components
#    COMMON:    ON
#    BATCHED:   ON
#    BLAS:      ON
#    LAPACK:    ON
#    GRAPH:     ON
#    SPARSE:    ON
#    ODE:       ON
#
# Kokkos Kernels TPLs
#    (None)
# ================================
#
# -- Creating ETI files for Batched_Gemm_nt_nt_bll
# -- Creating ETI files for Batched_Gemm_nt_t_bll
# -- Creating ETI files for Batched_Gemm_t_nt_bll
# -- Creating ETI files for Batched_Gemm_t_t_bll
# -- Creating ETI files for Batched_Gemm_nt_nt_blr
# -- Creating ETI files for Batched_Gemm_nt_t_blr
# -- Creating ETI files for Batched_Gemm_t_nt_blr
# -- Creating ETI files for Batched_Gemm_t_t_blr
# -- Creating ETI files for Blas1_abs
# -- Creating ETI files for Blas1_abs_mv
# -- Creating ETI files for Blas1_scal
# -- Creating ETI files for Blas1_scal_mv
# -- Creating ETI files for Blas1_dot
# -- Creating ETI files for Blas1_dot_mv
# -- Creating ETI files for Blas1_axpby
# -- Creating ETI files for Blas1_axpby_mv
# -- Creating ETI files for Blas1_update
# -- Creating ETI files for Blas1_update_mv
# -- Creating ETI files for Blas1_sum
# -- Creating ETI files for Blas1_sum_mv
# -- Creating ETI files for Blas1_nrm1
# -- Creating ETI files for Blas1_nrm1_mv
# -- Creating ETI files for Blas1_nrm2w
# -- Creating ETI files for Blas1_nrm2w_mv
# -- Creating ETI files for Blas1_nrminf
# -- Creating ETI files for Blas1_nrminf_mv
# -- Creating ETI files for Blas1_iamax
# -- Creating ETI files for Blas1_iamax_mv
# -- Creating ETI files for Blas1_nrm2
# -- Creating ETI files for Blas1_nrm2_mv
# -- Creating ETI files for Blas1_mult
# -- Creating ETI files for Blas1_mult_mv
# -- Creating ETI files for Blas1_reciprocal
# -- Creating ETI files for Blas1_reciprocal_mv
# -- Creating ETI files for Blas1_rot
# -- Creating ETI files for Blas1_rotg
# -- Creating ETI files for Blas1_rotm
# -- Creating ETI files for Blas1_rotmg
# -- Creating ETI files for Blas1_swap
# -- Creating ETI files for Blas2_gemv
# -- Creating ETI files for Blas2_ger
# -- Creating ETI files for Blas2_syr
# -- Creating ETI files for Blas2_syr2
# -- Creating ETI files for Blas3_gemm
# -- Creating ETI files for Blas3_trsm
# -- Creating ETI files for Blas3_trmm
# -- Creating ETI files for Lapack_gesv
# -- Creating ETI files for Lapack_trtri
# -- Creating ETI files for Lapack_svd
# -- Creating ETI files for Graph_color_d1
# -- Creating ETI files for Sparse_spmv_struct
# -- Creating ETI files for Sparse_spmv_mv_struct
# -- Creating ETI files for Sparse_spmv_bsrmatrix
# -- Creating ETI files for Sparse_spmv_mv_bsrmatrix
# -- Creating ETI files for Sparse_spmv
# -- Creating ETI files for Sparse_spmv_mv
# -- Creating ETI files for Sparse_spgemm_symbolic
# -- Creating ETI files for Sparse_spgemm_numeric
# -- Creating ETI files for Sparse_spgemm_noreuse
# -- Creating ETI files for Sparse_bspgemm_numeric
# -- Creating ETI files for Sparse_spgemm_jacobi
# -- Creating ETI files for Sparse_spadd_symbolic
# -- Creating ETI files for Sparse_spadd_numeric
# -- Creating ETI files for Sparse_spiluk_symbolic
# -- Creating ETI files for Sparse_spiluk_numeric
# -- Creating ETI files for Sparse_par_ilut_symbolic
# -- Creating ETI files for Sparse_par_ilut_numeric
# -- Creating ETI files for Sparse_gmres
# -- Creating ETI files for Sparse_sptrsv_symbolic
# -- Creating ETI files for Sparse_sptrsv_solve
# -- Creating ETI files for Sparse_trsv
# -- Creating ETI files for Sparse_gauss_seidel_symbolic
# -- Creating ETI files for Sparse_gauss_seidel_numeric
# -- Creating ETI files for Sparse_gauss_seidel_apply
# -- Configuring done (1.3s)
# -- Generating done (0.1s)
# -- Build files have been written to: /Users/benwibking/amrex_codes/chemistry/jaff/examples/build

# %% [markdown]
# * **Build with parallel compilation:**

# %%
!   cmake --build build -j
# Out:
# [2/3] Building CXX object CMakeFiles/chemistry_ode.dir/chemistry_ode.cpp.oake
# FAILED: [code=1] CMakeFiles/chemistry_ode.dir/chemistry_ode.cpp.o
# /usr/bin/c++ -DKOKKOS_DEPENDENCE -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkos-build -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkos-build/core/src -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkos-src/core/src -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkos-build/containers/src -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkos-src/containers/src -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkos-build/algorithms/src -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkos-src/algorithms/src -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkos-build/simd/src -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkos-src/simd/src -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-build -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-src/common/src -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-src/common/impl -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-src/batched -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-build/batched/eti -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-src/batched/dense/src -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-src/batched/dense/impl -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-src/batched/sparse/src -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-src/batched/sparse/impl -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-src/blas/src -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-src/blas/impl -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-src/blas/eti -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-build/blas/eti -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-src/blas/tpls -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-src/lapack/src -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-src/lapack/impl -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-src/lapack/eti -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-build/lapack/eti -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-src/lapack/tpls -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-src/graph/src -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-src/graph/impl -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-src/graph/eti -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-build/graph/eti -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-src/sparse/src -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-src/sparse/impl -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-src/sparse/eti -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-build/sparse/eti -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-src/sparse/tpls -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-src/ode/src -I/Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkoskernels-src/ode/impl -isystem /Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkos-src/tpls/desul/include -isystem /Users/benwibking/amrex_codes/chemistry/jaff/examples/build/_deps/kokkos-src/tpls/mdspan/include -std=c++1 ...
# In file included from /Users/benwibking/amrex_codes/chemistry/jaff/examples/chemistry_ode.cpp:7:
# /Users/benwibking/amrex_codes/chemistry/jaff/examples/chemistry_ode.hpp:113:39: error: use of undeclared identifier 'lnTe'
#   113 |         const double x0 = Kokkos::pow(lnTe, 2);
#       |                                       ^
# /Users/benwibking/amrex_codes/chemistry/jaff/examples/chemistry_ode.hpp:114:39: error: use of undeclared identifier 'lnTe'
#   114 |         const double x1 = Kokkos::pow(lnTe, 3);
#       |                                       ^
# /Users/benwibking/amrex_codes/chemistry/jaff/examples/chemistry_ode.hpp:115:39: error: use of undeclared identifier 'lnTe'
#   115 |         const double x2 = Kokkos::pow(lnTe, 4);
#       |                                       ^
# /Users/benwibking/amrex_codes/chemistry/jaff/examples/chemistry_ode.hpp:116:39: error: use of undeclared identifier 'lnTe'
#   116 |         const double x3 = Kokkos::pow(lnTe, 5);
#       |                                       ^
# /Users/benwibking/amrex_codes/chemistry/jaff/examples/chemistry_ode.hpp:117:39: error: use of undeclared identifier 'lnTe'
#   117 |         const double x4 = Kokkos::pow(lnTe, 6);
#       |                                       ^
# /Users/benwibking/amrex_codes/chemistry/jaff/examples/chemistry_ode.hpp:118:39: error: use of undeclared identifier 'lnTe'
#   118 |         const double x5 = Kokkos::pow(lnTe, 7);
#       |                                       ^
# /Users/benwibking/amrex_codes/chemistry/jaff/examples/chemistry_ode.hpp:119:39: error: use of undeclared identifier 'lnTe'
#   119 |         const double x6 = Kokkos::pow(lnTe, 8);
#       |                                       ^
# /Users/benwibking/amrex_codes/chemistry/jaff/examples/chemistry_ode.hpp:120:48: error: use of undeclared identifier 'invTe'
#   120 |         const double x7 = 3.92e-13*Kokkos::pow(invTe, 0.63529999999999998);
#       |                                                ^
# /Users/benwibking/amrex_codes/chemistry/jaff/examples/chemistry_ode.hpp:121:39: error: use of undeclared identifier 'lnTe'
#   121 |         const double x8 = Kokkos::pow(lnTe, 9);
#       |                                       ^
# /Users/benwibking/amrex_codes/chemistry/jaff/examples/chemistry_ode.hpp:128:57: error: use of undeclared identifier 'invT'
#   128 |         const double x13 = 3.0e-11*Kokkos::exp(-52000.0*invT);
#       |                                                         ^
# /Users/benwibking/amrex_codes/chemistry/jaff/examples/chemistry_ode.hpp:132:41: error: use of undeclared identifier 'invT'
#   132 |         const double x17 = Kokkos::sqrt(invT);
#       |                                         ^
# /Users/benwibking/amrex_codes/chemistry/jaff/examples/chemistry_ode.hpp:135:40: error: use of undeclared identifier 'T32'
#   135 |         const double x20 = Kokkos::pow(T32, -0.38);
#       |                                        ^
# /Users/benwibking/amrex_codes/chemistry/jaff/examples/chemistry_ode.hpp:136:32: error: use of undeclared identifier 'T32'
#   136 |         const double x21 = 1.0/T32;
#       |                                ^
# /Users/benwibking/amrex_codes/chemistry/jaff/examples/chemistry_ode.hpp:137:40: error: use of undeclared identifier 'T32'
#   137 |         const double x22 = Kokkos::pow(T32, -0.59999999999999998);
#       |                                        ^
# /Users/benwibking/amrex_codes/chemistry/jaff/examples/chemistry_ode.hpp:138:40: error: use of undeclared identifier 'T32'
#   138 |         const double x23 = Kokkos::pow(T32, -0.55000000000000004);
#       |                                        ^
# /Users/benwibking/amrex_codes/chemistry/jaff/examples/chemistry_ode.hpp:148:47: error: use of undeclared identifier 'invT'
#   148 |         const double x33 = Kokkos::exp(-270.0*invT);
#       |                                               ^
# /Users/benwibking/amrex_codes/chemistry/jaff/examples/chemistry_ode.hpp:149:41: error: use of undeclared identifier 'T32'; did you mean 'x32'?
#   149 |         const double x34 = Kokkos::sqrt(T32);
#       |                                         ^~~
#       |                                         x32
# /Users/benwibking/amrex_codes/chemistry/jaff/examples/chemistry_ode.hpp:147:22: note: 'x32' declared here
#   147 |         const double x32 = Kokkos::pow(Tgas, 0.23999999999999999)*(3.1699999999999999*Kokkos::exp(4.1839999999999999e-7*Tgas) + 1.0);
#       |                      ^
# /Users/benwibking/amrex_codes/chemistry/jaff/examples/chemistry_ode.hpp:153:40: error: use of undeclared identifier 'T32'
#   153 |         const double x38 = Kokkos::pow(T32, -0.156)*Kokkos::exp(-1.4099999999999999*invT);
#       |                                        ^
# /Users/benwibking/amrex_codes/chemistry/jaff/examples/chemistry_ode.hpp:153:85: error: use of undeclared identifier 'invT'
#   153 |         const double x38 = Kokkos::pow(T32, -0.156)*Kokkos::exp(-1.4099999999999999*invT);
#       |                                                                                     ^
# fatal error: too many errors emitted, stopping now [-ferror-limit=]
# 20 errors generated.
# ninja: build stopped: subcommand failed.

# %% [markdown]
# * **Run the chemistry solver:**

# %%
!   ./build/chemistry_ode
# Out:
# zsh:1: no such file or directory: ./build/chemistry_ode

# %% [markdown]
# * **Or, run with custom time interval (1e12 seconds):**

# %%
!   ./build/chemistry_ode 1e12
# Out:
# zsh:1: no such file or directory: ./build/chemistry_ode
